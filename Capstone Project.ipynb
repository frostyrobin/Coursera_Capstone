# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods
#
# ### Finding the best location to build student dormitories in Davao City
#
# Student dormitories can be a lucrative business venture in Davao city since majority of college students studying in Davao are from the provinces. This leads to higher demands for dormitories and apartments since these students would usually opt for dormitories and apartments to cater their stay in the city. And, great spots to consider would be those **located near universities, food courts, diners, malls, convenience stores, gyms, and bars.**
#
#
# ### Data
#
# The data used for this study would mostly come from **Foursquare's data**. I would be identifying the schools located in downtown Davao, filter venues, and perform clustering. A heatmap would then be used to identify hotzones where there's an abundance of venues meeting our criteria.
#
# For simplicity, we would not be considering the cost of real estate in this study, and we would only be concerned in identifying spots that would most likely garner interest from potential tenants.
#
# ### Methodology
#
# The **first** step for the study is gathering data on nearby universities and colleges, and venues.
#
# **Second** is filtering the venues and only taking in venues that match our desired categories (food courts, diners, malls, convenience stores, gyms, and bars).
#
# **Third** is clustering our schools and venues datasets.
#
# **Fourth** is performing a visualization of the school clusters and creating a heatmap for the venues.
#
# **Fifth** is gathering insights from the results

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# ### Installing and importing libraries

# %%
# !pip install folium
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
# !pip install shapely
# !pip install pyproj
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: shapely in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.7.1)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: pyproj in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (3.0.1)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pyproj) (2020.12.5)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import requests

from pandas.io.json import json_normalize

# %% [markdown]
# ### Coordinates of downtown Davao

# %%
lat1 = 7.0720
long1 = 125.6132

# %%
CLIENT_ID = '3ZY1AKOGOHUSFK00ED5DICVW55PVGYBKPUJ2VDH05LFA1VXP' # your Foursquare ID
CLIENT_SECRET = 'F3G1HEW4ELDS3RDRSPLURY05KZ3QFUDWN43BBEYNWZSIOE1O' # your Foursquare Secret
ACCESS_TOKEN = '1YCNQ3CGXALU4TK5ED5D5R03CYLWWZIAE2MG3ZPLZRQ5RJAU' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3ZY1AKOGOHUSFK00ED5DICVW55PVGYBKPUJ2VDH05LFA1VXP
# CLIENT_SECRET:F3G1HEW4ELDS3RDRSPLURY05KZ3QFUDWN43BBEYNWZSIOE1O

# %% [markdown]
# ## Find college and universities in downtown area

# %%
search_query = 'College & University'
radius = 1000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat1, long1,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3ZY1AKOGOHUSFK00ED5DICVW55PVGYBKPUJ2VDH05LFA1VXP&client_secret=F3G1HEW4ELDS3RDRSPLURY05KZ3QFUDWN43BBEYNWZSIOE1O&ll=7.072,125.6132&oauth_token=1YCNQ3CGXALU4TK5ED5D5R03CYLWWZIAE2MG3ZPLZRQ5RJAU&v=20180605&query=College & University&radius=1000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60a82072189b5f6a445880a5'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4e67a8feaeb7e985aad4d78b',
#     'name': 'Holy Child College',
#     'location': {'address': 'Jacinto Street',
#      'lat': 7.0726786116949665,
#      'lng': 125.61559526265405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0726786116949665,
#        'lng': 125.61559526265405}],
#      'distance': 275,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Davao City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Jacinto Street', '8000 Davao City']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4dedec8f2271e7b44629181b',
#     'name': 'Holy Cross Of Davao College, Inc.',
#     'location': {'address': 'Sta. Ana Ave.',
#      'crossStreet': 'Sta Ana Ave',
#      'lat': 7.076794050590078,
#      'lng': 125.61423886731788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076794050590078,
#        'lng': 125.61423886731788}],
#      'distance': 545,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Davao City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Sta. Ana Ave. (Sta Ana Ave)', '8000 Davao City']},
#     'categories': [{'id': '4d4b7105d754a06372d81259',
#       'name': 'College & University',
#       'pluralName': 'Colleges & Universities',
#       'shortName': 'College & Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '529d88fb11d233ad61d0fa26',
#     'name': 'Holy Cross of Davao College Main Library',
#     'location': {'lat': 7.077258586883545,
#      'lng': 125.61612701416016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077258586883545,
#        'lng': 125.61612701416016}],
#      'distance': 668,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '5297cda211d2904f1e7eb077',
#     'name': 'San Pedro College PL 412',
#     'location': {'lat': 7.077899282999926,
#      'lng': 125.61511465274823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077899282999926,
#        'lng': 125.61511465274823}],
#      'distance': 689,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50132d6de4b07f20b2d2f63e',
#     'name': 'San Pedro College CT 303',
#     'location': {'crossStreet': 'Guzman Street',
#      'lat': 7.0780211928489765,
#      'lng': 125.61564866357756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0780211928489765,
#        'lng': 125.61564866357756}],
#      'distance': 722,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Guzman Street', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53d838ab498eb7cff0440d3a',
#     'name': 'San Pedro College Sky Gym',
#     'location': {'lat': 7.078128690603049,
#      'lng': 125.61538165860578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.078128690603049,
#        'lng': 125.61538165860578}],
#      'distance': 723,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50b9cddfe4b0fb1ae31d5808',
#     'name': 'San Pedro College Audio Visual Room',
#     'location': {'address': '12 C. Guzman Street',
#      'lat': 7.078119168438813,
#      'lng': 125.61570740455248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.078119168438813,
#        'lng': 125.61570740455248}],
#      'distance': 735,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['12 C. Guzman Street', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1ac941735',
#       'name': 'College Theater',
#       'pluralName': 'College Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '5067a88fe4b0da82c6b3d7e8',
#     'name': 'San Pedro College Open Court',
#     'location': {'crossStreet': 'Guzman Street',
#      'lat': 7.078100621461386,
#      'lng': 125.61562436865964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.078100621461386,
#        'lng': 125.61562436865964}],
#      'distance': 730,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Guzman Street', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1e1941735',
#       'name': 'Basketball Court',
#       'pluralName': 'Basketball Courts',
#       'shortName': 'Basketball Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4d96a26eb188721e667dfc36',
#     'name': 'Intercity College of Science and Technology',
#     'location': {'address': 'Araullo Ext',
#      'crossStreet': 'Jacinto Ext',
#      'lat': 7.0786234899814096,
#      'lng': 125.6090373599442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0786234899814096,
#        'lng': 125.6090373599442}],
#      'distance': 868,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Araullo Ext (Jacinto Ext)', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '520b04fe498efc5ac25d0ecd',
#     'name': 'San Pedro College Learning Commons',
#     'location': {'address': 'San Pedro College Library',
#      'lat': 7.07817206420322,
#      'lng': 125.61545118719833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.07817206420322,
#        'lng': 125.61545118719833}],
#      'distance': 730,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Davao City',
#      'state': 'Davao del Sur',
#      'country': 'Pilipinas',
#      'formattedAddress': ['San Pedro College Library',
#       '8000 Davao',
#       'Davao del Sur']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4fa311bbe4b07ed218daf20e',
#     'name': 'San Pedro College Gym',
#     'location': {'address': 'Guzman St',
#      'lat': 7.078066783693009,
#      'lng': 125.61565165015391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.078066783693009,
#        'lng': 125.61565165015391}],
#      'distance': 727,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'neighborhood': 'Poblacion',
#      'city': 'Davao City',
#      'state': 'Davao del Sur',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Guzman St', '8000 Davao City', 'Davao del Sur']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4f84f58fe4b0ae40e126886c',
#     'name': 'San Pedro College Saint Therese Building',
#     'location': {'address': 'Guzman St, Davao City',
#      'lat': 7.078151656595301,
#      'lng': 125.61556201906811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.078151656595301,
#        'lng': 125.61556201906811}],
#      'distance': 732,
#      'cc': 'PH',
#      'city': 'Davao City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Guzman St, Davao City', 'Davao City']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4ff13272e4b00d073bf893d3',
#     'name': 'San Pedro College, PG Bldg.',
#     'location': {'address': '12 Guzman St.',
#      'lat': 7.077969969327987,
#      'lng': 125.61571314440175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077969969327987,
#        'lng': 125.61571314440175}],
#      'distance': 720,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['12 Guzman St.', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4fa36d6fe4b0c1088ccb50f5',
#     'name': 'San Pedro College - Saint Dominic Building',
#     'location': {'address': '12 C. Guzman St.',
#      'lat': 7.07806467322555,
#      'lng': 125.61562868278514,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.07806467322555,
#        'lng': 125.61562868278514}],
#      'distance': 726,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['12 C. Guzman St.', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4fd5bf50e4b02c7fc4ee8111',
#     'name': 'Guidance Testing Center (San Pedro College)',
#     'location': {'address': '12 C. Guzman Street',
#      'lat': 7.072348181199501,
#      'lng': 125.6126688378759,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.072348181199501,
#        'lng': 125.6126688378759}],
#      'distance': 70,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['12 C. Guzman Street', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50a31f12e4b0446626c06c52',
#     'name': 'B501 AdDU College',
#     'location': {'lat': 7.072456910646399,
#      'lng': 125.61318684417206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.072456910646399,
#        'lng': 125.61318684417206}],
#      'distance': 50,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4f8d12b96d86c2aa493fd818',
#     'name': 'Holy Child College of Davao - Gym',
#     'location': {'address': 'E. Jacinto St.',
#      'lat': 7.070676779951694,
#      'lng': 125.61402797698975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.070676779951694,
#        'lng': 125.61402797698975}],
#      'distance': 173,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['E. Jacinto St.', '8000 Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '51248cd3e4b0dab8c86b92dd',
#     'name': 'ComLab 4, STI COLLEGE OF DAVAO',
#     'location': {'lat': 7.074031391371395,
#      'lng': 125.61259941409837,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.074031391371395,
#        'lng': 125.61259941409837}],
#      'distance': 235,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d19f941735',
#       'name': 'College Technology Building',
#       'pluralName': 'College Technology Buildings',
#       'shortName': 'Technology',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50f11fd5e4b070ffff04c114',
#     'name': 'ComLab2, STI COLLEGE OF DAVAO',
#     'location': {'lat': 7.073933651536688,
#      'lng': 125.61225763462834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.073933651536688,
#        'lng': 125.61225763462834}],
#      'distance': 239,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d19f941735',
#       'name': 'College Technology Building',
#       'pluralName': 'College Technology Buildings',
#       'shortName': 'Technology',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '51f1d43d498e5c6ef2d9b7de',
#     'name': 'Holy Child College of Davao',
#     'location': {'lat': 7.071347881555198,
#      'lng': 125.61469812184168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.071347881555198,
#        'lng': 125.61469812184168}],
#      'distance': 180,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '4f8d0d046d86c2aa493f3dd0',
#     'name': 'Holy Child College of Davao',
#     'location': {'address': 'E. Jacinto St.',
#      'lat': 7.0709142252827375,
#      'lng': 125.61435334166103,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0709142252827375,
#        'lng': 125.61435334166103}],
#      'distance': 175,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['E. Jacinto St.', '8000 Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50eb8b98e4b0ad5f846abe85',
#     'name': 'STI COLLEGE of Acacia',
#     'location': {'lat': 7.073951025833367,
#      'lng': 125.61277030328922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.073951025833367,
#        'lng': 125.61277030328922}],
#      'distance': 222,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d19f941735',
#       'name': 'College Technology Building',
#       'pluralName': 'College Technology Buildings',
#       'shortName': 'Technology',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '5697260b498ee2b4d0214158',
#     'name': 'AVR, STI College - Davao',
#     'location': {'address': 'Acacia St. Corner J. P. Laurel Ave.',
#      'lat': 7.074209,
#      'lng': 125.61267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.074209,
#        'lng': 125.61267}],
#      'distance': 252,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Acacia St. Corner J. P. Laurel Ave.',
#       'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50b9c53ee4b0040a8484b977',
#     'name': 'Davao Doctors College Foodcourt',
#     'location': {'lat': 7.074253433503985,
#      'lng': 125.61368348625376,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.074253433503985,
#        'lng': 125.61368348625376}],
#      'distance': 256,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50f75a58e4b03547f5bb2dba',
#     'name': 'Room 102, STI COLLEGE of Davao',
#     'location': {'lat': 7.074482440948486,
#      'lng': 125.6127700805664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.074482440948486,
#        'lng': 125.6127700805664}],
#      'distance': 280,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '558a7658498e5a458270a56d',
#     'name': 'STI College of Davao',
#     'location': {'address': '501 Lim Building',
#      'crossStreet': 'J. P. Laurel Avenue, corner Acacia',
#      'lat': 7.073867892646896,
#      'lng': 125.61160077313515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.073867892646896,
#        'lng': 125.61160077313515}],
#      'distance': 272,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['501 Lim Building (J. P. Laurel Avenue, corner Acacia)',
#       'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '504830bee4b0f1b4ccfae8ec',
#     'name': 'College Assurance Plan  (CAP)',
#     'location': {'lat': 7.07070874351854,
#      'lng': 125.60740848207494,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.07070874351854,
#        'lng': 125.60740848207494}],
#      'distance': 655,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '564bf0ca498ebf8fee3ff657',
#     'name': 'San Pedro College Internet Laboratory',
#     'location': {'lat': 7.073855619779398,
#      'lng': 125.61522145519756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.073855619779398,
#        'lng': 125.61522145519756}],
#      'distance': 304,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50c84dd5e4b0e3c2219b5827',
#     'name': 'STI COLLEGE OF DAVAO',
#     'location': {'lat': 7.07411239756623,
#      'lng': 125.61264065299393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.07411239756623,
#        'lng': 125.61264065299393}],
#      'distance': 243,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '54f423ab498e38495bcb4b9c',
#     'name': 'Brokenshire College of Nursing',
#     'location': {'lat': 7.069059,
#      'lng': 125.614691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.069059,
#        'lng': 125.614691}],
#      'distance': 366,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '55fab2c3498ec7cc28b6ea38',
#     'name': 'San Pedro College Ladies Dormitory',
#     'location': {'lat': 7.075366973876953,
#      'lng': 125.6134262084961,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.075366973876953,
#        'lng': 125.6134262084961}],
#      'distance': 375,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '50d6bd64f2e782732e3e130b',
#     'name': 'San Pedro College PG',
#     'location': {'address': 'Guzman Street',
#      'crossStreet': 'Guzman Street',
#      'lat': 7.075638368986195,
#      'lng': 125.6110453605652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.075638368986195,
#        'lng': 125.6110453605652}],
#      'distance': 469,
#      'postalCode': '80000',
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Guzman Street (Guzman Street)',
#       '80000 Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '568b912238fa04af55e834f0',
#     'name': 'STI College Davao Faculty Room',
#     'location': {'lat': 7.076509,
#      'lng': 125.612167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076509,
#        'lng': 125.612167}],
#      'distance': 514,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '54ed8d15498ec36f92be9858',
#     'name': 'Metro College Davao',
#     'location': {'address': 'Ponciano Street Davao City',
#      'lat': 7.068988,
#      'lng': 125.609563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.068988,
#        'lng': 125.609563}],
#      'distance': 523,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Ponciano Street Davao City']},
#     'categories': [{'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'shortName': 'Community College',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '5382dec0498e871d4be30f86',
#     'name': 'Samson Polytechnic College of Davao',
#     'location': {'lat': 7.073939,
#      'lng': 125.617567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.073939,
#        'lng': 125.617567}],
#      'distance': 528,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '529845c111d21b0f97109c46',
#     'name': 'san pedro college dorm',
#     'location': {'lat': 7.077972992321344,
#      'lng': 125.61504523108017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077972992321344,
#        'lng': 125.61504523108017}],
#      'distance': 695,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53180bf9498eeba537672354',
#     'name': 'Holy Cross of Davao College IT Laboratory',
#     'location': {'address': 'Sta. Ana Avenue, Davao City',
#      'crossStreet': 'Sta. Ana Avenue',
#      'lat': 7.07666,
#      'lng': 125.61541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.07666,
#        'lng': 125.61541}],
#      'distance': 573,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Sta. Ana Avenue, Davao City (Sta. Ana Avenue)',
#       '8000 Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53b277e8498e4cf63edfcd2f',
#     'name': 'Cross Office, Holy Cross of Davao College, Inc.',
#     'location': {'address': 'Sta Ana Avenue Davao City',
#      'lat': 7.076824479363313,
#      'lng': 125.61654579379419,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076824479363313,
#        'lng': 125.61654579379419}],
#      'distance': 651,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Sta Ana Avenue Davao City', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '55a60fde498ee51f6b3afe28',
#     'name': 'Atbang San Pedro College',
#     'location': {'lat': 7.077229976654053,
#      'lng': 125.61482238769531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077229976654053,
#        'lng': 125.61482238769531}],
#      'distance': 609,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '5689b727498e85b9529f2df1',
#     'name': 'University of Mindanao College of Business Administratiom',
#     'location': {'address': 'Bolton St.',
#      'lat': 7.0677423,
#      'lng': 125.609825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0677423,
#        'lng': 125.609825}],
#      'distance': 603,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Bolton St.', 'Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'shortName': 'Science',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '576e6fea498e95407f46c4da',
#     'name': 'Holy Cross Of Davao College Speech Laboratory',
#     'location': {'address': 'Holy Cross Of Davao College',
#      'crossStreet': 'Sta. Ana Avenue',
#      'lat': 7.076903,
#      'lng': 125.61569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076903,
#        'lng': 125.61569}],
#      'distance': 611,
#      'postalCode': '8000',
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Holy Cross Of Davao College (Sta. Ana Avenue)',
#       '8000 Lungsod ng Dabaw']},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '51cd24bf498ec7793178b35c',
#     'name': 'Davao Doctors College 5th Floor',
#     'location': {'lat': 7.071375846862793,
#      'lng': 125.60758972167969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.071375846862793,
#        'lng': 125.60758972167969}],
#      'distance': 623,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '561651a7498e2ca5fe49a40c',
#     'name': 'Holy Cross of Davao College E-Library',
#     'location': {'lat': 7.076898,
#      'lng': 125.616118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076898,
#        'lng': 125.616118}],
#      'distance': 633,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53aa39dc498ea6ed8893e7ba',
#     'name': 'San Pedro College-  Research laboratoy',
#     'location': {'lat': 7.0772294998168945,
#      'lng': 125.61559295654297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.0772294998168945,
#        'lng': 125.61559295654297}],
#      'distance': 639,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1b3941735',
#       'name': 'Medical School',
#       'pluralName': 'Medical Schools',
#       'shortName': 'Medical School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '581fdc7b4e1d9a1924c6766f',
#     'name': 'Saint Albans College of Technology',
#     'location': {'lat': 7.066941,
#      'lng': 125.611478,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.066941,
#        'lng': 125.611478}],
#      'distance': 594,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '56565cc8498ef675b9d490f7',
#     'name': 'San Pedro College CT-306',
#     'location': {'lat': 7.077397,
#      'lng': 125.61556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077397,
#        'lng': 125.61556}],
#      'distance': 654,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '584faf2c14f8f43d3823081b',
#     'name': 'Holy Cross Of Davao College Bookstore',
#     'location': {'lat': 7.077622,
#      'lng': 125.6151,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077622,
#        'lng': 125.6151}],
#      'distance': 660,
#      'cc': 'PH',
#      'city': 'Davao City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Davao City']},
#     'categories': [{'id': '4bf58dd8d48988d1b1941735',
#       'name': 'College Bookstore',
#       'pluralName': 'College Bookstores',
#       'shortName': 'College Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53b4a542498eb33cef835ac3',
#     'name': 'holy cross of davao college psych laboratory',
#     'location': {'lat': 7.076909,
#      'lng': 125.616559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076909,
#        'lng': 125.616559}],
#      'distance': 660,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '56a96bf6498ed0803c4ca830',
#     'name': 'san pedro college Musalla prayer room',
#     'location': {'lat': 7.077368,
#      'lng': 125.615835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.077368,
#        'lng': 125.615835}],
#      'distance': 664,
#      'cc': 'PH',
#      'country': 'Pilipinas'},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False},
#    {'id': '53952617498ecef1832267fc',
#     'name': 'BA Lab, Holy Cross of Davao College, Inc.',
#     'location': {'lat': 7.076786994934082,
#      'lng': 125.61659240722656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 7.076786994934082,
#        'lng': 125.61659240722656}],
#      'distance': 651,
#      'cc': 'PH',
#      'city': 'Lungsod ng Dabaw',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Lungsod ng Dabaw']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a47',
#       'name': 'Religious School',
#       'pluralName': 'Religious Schools',
#       'shortName': 'Religious School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1621631090',
#     'hasPerk': False}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
results['response']['venues'][0]
# Out:
# {'id': '4e67a8feaeb7e985aad4d78b',
#  'name': 'Holy Child College',
#  'location': {'address': 'Jacinto Street',
#   'lat': 7.0726786116949665,
#   'lng': 125.61559526265405,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 7.0726786116949665,
#     'lng': 125.61559526265405}],
#   'distance': 275,
#   'postalCode': '8000',
#   'cc': 'PH',
#   'city': 'Davao City',
#   'country': 'Pilipinas',
#   'formattedAddress': ['Jacinto Street', '8000 Davao City']},
#  'categories': [{'id': '4bf58dd8d48988d13d941735',
#    'name': 'High School',
#    'pluralName': 'High Schools',
#    'shortName': 'High School',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1621631090',
#  'hasPerk': False}

# %%
venue = results['response']['venues'][0]
    

# filter columns
#nearby_venues =nearby_venues.loc[:, filtered_columns]

columns = [venue['name'],venue['categories'][0]['name'],venue['location']['lat'],venue['location']['lng']]
schools = pd.DataFrame()

# %%
name = []
cat = []
lat = []
long = []

# %%
for x in results['response']['venues']:
    name1 = x['name']
    catg = x['categories'][0]['name']
    lat1 = x['location']['lat']
    long1= x['location']['lng']
    name.append(name1)
    cat.append(catg)
    lat.append(lat1)
    long.append(long1)

# %%
schools['Name'] = name
schools['Category'] = cat
schools['Latitude'] = lat
schools['Longitude'] = long


schools.head()
# Out:
#                                        Name              Category  Latitude  \
# 0                        Holy Child College           High School  7.072679
# 1         Holy Cross Of Davao College, Inc.  College & University  7.076794
# 2  Holy Cross of Davao College Main Library       College Library  7.077259
# 3                  San Pedro College PL 412     College Classroom  7.077899
# 4                  San Pedro College CT 303     College Classroom  7.078021
#
#     Longitude
# 0  125.615595
# 1  125.614239
# 2  125.616127
# 3  125.615115
# 4  125.615649

# %% [markdown]
# ## Find venues in downtown area

# %% [markdown]
# urlv = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat1, long1,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

# %%
radius1 = 1000
LIMIT1 = 2000
lat2 = 7.0720
long2 = 125.6132

urlv = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat2, 
            long2, 
            radius1, 
            LIMIT1)

# %%
results1 = requests.get(urlv).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '60a820732f8b8f1c45f73278'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Poblacion',
#   'headerFullLocation': 'Poblacion, Davao City',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 212,
#   'suggestedBounds': {'ne': {'lat': 7.081000009000009,
#     'lng': 125.62225207109651},
#    'sw': {'lat': 7.062999990999991, 'lng': 125.6041479289035}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9dd234f964a5200dbf36e3',
#        'name': 'Marco Polo Davao',
#        'location': {'address': 'Roxas Ave',
#         'crossStreet': 'C M Recto Ave',
#         'lat': 7.0720768904109725,
#         'lng': 125.61134576797485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0720768904109725,
#           'lng': 125.61134576797485}],
#         'distance': 205,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'neighborhood': 'Poblacion',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Roxas Ave (C M Recto Ave)',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9dd234f964a5200dbf36e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfe012bee9cb60c15629dad',
#        'name': 'Harley Boulevard Motor Cafe',
#        'location': {'address': 'J. Luna St.',
#         'crossStreet': 'btwn J. Dela Cruz & Guerrero St.',
#         'lat': 7.072273280161847,
#         'lng': 125.61560030988757,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.072273280161847,
#           'lng': 125.61560030988757}],
#         'distance': 266,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['J. Luna St. (btwn J. Dela Cruz & Guerrero St.)',
#          '8000 Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfe012bee9cb60c15629dad-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f273367e4b0d609c9494240',
#        'name': 'Cafe Marco',
#        'location': {'address': 'Marco Polo Hotel',
#         'crossStreet': 'C. M. Recto St.,',
#         'lat': 7.072105041242055,
#         'lng': 125.61186757699707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.072105041242055,
#           'lng': 125.61186757699707}],
#         'distance': 147,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'neighborhood': 'Poblacion',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Marco Polo Hotel (C. M. Recto St.,)',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f273367e4b0d609c9494240-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6cb742b0fba3f50e6a9a51',
#        'name': 'Roxas Night Market',
#        'location': {'address': 'Roxas Ave',
#         'lat': 7.070947791509277,
#         'lng': 125.61330966991832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.070947791509277,
#           'lng': 125.61330966991832}],
#         'distance': 117,
#         'cc': 'PH',
#         'neighborhood': 'Poblacion',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Roxas Ave', 'Lungsod ng Dabaw', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1f7941735',
#          'name': 'Flea Market',
#          'pluralName': 'Flea Markets',
#          'shortName': 'Flea Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6cb742b0fba3f50e6a9a51-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ef47203722e31c647a21e53',
#        'name': 'Sencha',
#        'location': {'address': 'Magsaysay Ave.',
#         'lat': 7.073686159227526,
#         'lng': 125.61428990584103,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.073686159227526,
#           'lng': 125.61428990584103}],
#         'distance': 222,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Magsaysay Ave.',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ef47203722e31c647a21e53-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '500a71a5ebca2b447ac984cf',
#        'name': 'Happy Lemon',
#        'location': {'address': 'The Peak, Gaisano Mall of Davao, J P Laurel Ave, Bajada',
#         'lat': 7.07711049052085,
#         'lng': 125.61441600336288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.07711049052085,
#           'lng': 125.61441600336288}],
#         'distance': 584,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['The Peak, Gaisano Mall of Davao, J P Laurel Ave, Bajada',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-500a71a5ebca2b447ac984cf-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc7d77f3c40a35d554b712e',
#        'name': 'Chippens',
#        'location': {'address': 'Roxas',
#         'lat': 7.070115510709253,
#         'lng': 125.61408325765399,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.070115510709253,
#           'lng': 125.61408325765399}],
#         'distance': 231,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Roxas', 'Davao City', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc7d77f3c40a35d554b712e-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b06a91797236a15a66788',
#        'name': 'Glamour Crab Buffet',
#        'location': {'address': 'Gomez',
#         'crossStreet': 'Roxas',
#         'lat': 7.0693528393314,
#         'lng': 125.61329037497404,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0693528393314,
#           'lng': 125.61329037497404}],
#         'distance': 294,
#         'cc': 'PH',
#         'city': 'Davao',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Gomez (Roxas)', 'Davao', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b06a91797236a15a66788-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f77f307e4b07024fb0e162b',
#        'name': 'Marco Polo Poolside',
#        'location': {'crossStreet': 'at CM Recto Ave',
#         'lat': 7.072109576420102,
#         'lng': 125.61103487719521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.072109576420102,
#           'lng': 125.61103487719521}],
#         'distance': 239,
#         'cc': 'PH',
#         'country': 'Pilipinas',
#         'formattedAddress': ['at CM Recto Ave', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d132951735',
#          'name': 'Hotel Pool',
#          'pluralName': 'Hotel Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f77f307e4b07024fb0e162b-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdf2aede4b082d077339a3b',
#        'name': 'Mic1 KTV',
#        'location': {'address': 'J.P. Laurel Ave.',
#         'lat': 7.075983735247778,
#         'lng': 125.61316326270588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.075983735247778,
#           'lng': 125.61316326270588}],
#         'distance': 443,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['J.P. Laurel Ave.',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d120941735',
#          'name': 'Karaoke Bar',
#          'pluralName': 'Karaoke Bars',
#          'shortName': 'Karaoke',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdf2aede4b082d077339a3b-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0cdc77257d6dcb886d9867',
#        'name': 'Ice Giants',
#        'location': {'address': 'Santa Ana Ave.',
#         'crossStreet': 'at J.P. Laurel Avenue',
#         'lat': 7.076652835889294,
#         'lng': 125.61458877439733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.076652835889294,
#           'lng': 125.61458877439733}],
#         'distance': 540,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Santa Ana Ave. (at J.P. Laurel Avenue)',
#          '8000 Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0cdc77257d6dcb886d9867-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5146abb3e4b0251c39b3eb28',
#        'name': 'My Skin Essentials',
#        'location': {'address': 'Jacinto Street',
#         'lat': 7.070519736022691,
#         'lng': 125.61540659316996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.070519736022691,
#           'lng': 125.61540659316996}],
#         'distance': 294,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Jacinto Street',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5146abb3e4b0251c39b3eb28-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c658ab119f3c9b6ae5f9dff',
#        'name': 'Pacific Spa',
#        'location': {'address': 'C.M. Recto Ave,',
#         'crossStreet': 'Roxas St.',
#         'lat': 7.071725076144522,
#         'lng': 125.61147341045125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.071725076144522,
#           'lng': 125.61147341045125}],
#         'distance': 193,
#         'cc': 'PH',
#         'country': 'Pilipinas',
#         'formattedAddress': ['C.M. Recto Ave, (Roxas St.)', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c658ab119f3c9b6ae5f9dff-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '508806a8e4b0b793e370fe3d',
#        'name': 'Dox Hub',
#        'location': {'address': 'Juan dela Cruz Street',
#         'lat': 7.0717783,
#         'lng': 125.61549,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0717783,
#           'lng': 125.61549}],
#         'distance': 254,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'neighborhood': 'Poblacion',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Juan dela Cruz Street',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-508806a8e4b0b793e370fe3d-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c77c08498e6a7f02ebdc2c',
#        'name': 'Coffee Grounds',
#        'location': {'address': 'Roxas Extension, Golden Lion Dormitel',
#         'lat': 7.066257411098499,
#         'lng': 125.61701379873908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.066257411098499,
#           'lng': 125.61701379873908}],
#         'distance': 765,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'neighborhood': 'Barangay 31',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Roxas Extension, Golden Lion Dormitel',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c77c08498e6a7f02ebdc2c-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5459fdb9498eed3c99a0ce85',
#        'name': 'Caffè Antoccino',
#        'location': {'address': '59 Guerrero',
#         'lat': 7.072803705714685,
#         'lng': 125.6166128156653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.072803705714685,
#           'lng': 125.6166128156653}],
#         'distance': 387,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['59 Guerrero',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5459fdb9498eed3c99a0ce85-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '526bca30498e46e8215a27c2',
#        'name': 'Mabini BBQ Haus',
#        'location': {'address': 'Mabini Street',
#         'lat': 7.068491741156339,
#         'lng': 125.61332684165363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.068491741156339,
#           'lng': 125.61332684165363}],
#         'distance': 390,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Mabini Street',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-526bca30498e46e8215a27c2-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f54a513e4b0bf6b5f897b90',
#        'name': 'Pastil BBQ Sa Ponce',
#        'location': {'address': 'Ponce St.',
#         'crossStreet': 'Juan Dela Cruz St.',
#         'lat': 7.070817286550607,
#         'lng': 125.61557028107534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.070817286550607,
#           'lng': 125.61557028107534}],
#         'distance': 293,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Ponce St. (Juan Dela Cruz St.)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f54a513e4b0bf6b5f897b90-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccc054b54f0b1f7303713ca',
#        'name': 'Tan-Ton Thai Massage',
#        'location': {'address': 'JP Laurel',
#         'lat': 7.075278670379594,
#         'lng': 125.61286114304968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.075278670379594,
#           'lng': 125.61286114304968}],
#         'distance': 366,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['JP Laurel', 'Davao City', 'Pilipinas']},
#        'categories': [{'id': '4d1cf8421a97d635ce361c31',
#          'name': 'Tanning Salon',
#          'pluralName': 'Tanning Salons',
#          'shortName': 'Tanning Salon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tanning_salon_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccc054b54f0b1f7303713ca-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f896a5ae4b0c71a71b10b41',
#        'name': 'Cafe Frances',
#        'location': {'address': 'Ground Floor The Pinnacle Hotel and Suites, Sta. Ana Avenue',
#         'lat': 7.076222182824272,
#         'lng': 125.61524152225961,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.076222182824272,
#           'lng': 125.61524152225961}],
#         'distance': 521,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Ground Floor The Pinnacle Hotel and Suites, Sta. Ana Avenue',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f896a5ae4b0c71a71b10b41-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d08bcbe4adb37041274fe54',
#        'name': 'Pancake House',
#        'location': {'address': 'Gaisano Mall, J P Laurel Ave',
#         'lat': 7.078162171699689,
#         'lng': 125.6142282716855,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.078162171699689,
#           'lng': 125.6142282716855}],
#         'distance': 695,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Gaisano Mall, J P Laurel Ave',
#          '8000 Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d08bcbe4adb37041274fe54-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf0d3dda09076b0d9c329d4',
#        'name': "Davao Dencia's Restaurant, Inc.",
#        'location': {'address': 'General Luna St.',
#         'crossStreet': 'cor. Ilustre St.',
#         'lat': 7.069639875928841,
#         'lng': 125.60669779268378,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.069639875928841,
#           'lng': 125.60669779268378}],
#         'distance': 764,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['General Luna St. (cor. Ilustre St.)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf0d3dda09076b0d9c329d4-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b91881eafb1f783ab8435',
#        'name': 'Casa De Amigos',
#        'location': {'lat': 7.071372969980646,
#         'lng': 125.61107781180834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.071372969980646,
#           'lng': 125.61107781180834}],
#         'distance': 244,
#         'cc': 'PH',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b91881eafb1f783ab8435-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583cbc17561ded188294071d',
#        'name': 'Bondi&Bourke',
#        'location': {'address': '115 P Pelayo St',
#         'lat': 7.067949571237114,
#         'lng': 125.60628029451563,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.067949571237114,
#           'lng': 125.60628029451563}],
#         'distance': 887,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['115 P Pelayo St',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-583cbc17561ded188294071d-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4520741838e44e899530f5',
#        'name': 'Thai Boran Massage',
#        'location': {'address': 'Camus St',
#         'crossStreet': 'Pardo de Tavera St.',
#         'lat': 7.072450813722844,
#         'lng': 125.6070127765347,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.072450813722844,
#           'lng': 125.6070127765347}],
#         'distance': 685,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Camus St (Pardo de Tavera St.)',
#          'Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4520741838e44e899530f5-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3a779fbf6d54811597cde1',
#        'name': 'Metro Card Club Davao',
#        'location': {'address': 'CVA Building, Quirino Street',
#         'lat': 7.075584510707617,
#         'lng': 125.6118790174616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.075584510707617,
#           'lng': 125.6118790174616}],
#         'distance': 424,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['CVA Building, Quirino Street',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d17c941735',
#          'name': 'Casino',
#          'pluralName': 'Casinos',
#          'shortName': 'Casino',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3a779fbf6d54811597cde1-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b50bfb0f964a520a93027e3',
#        'name': "People's Park",
#        'location': {'address': 'Palma Gil Street',
#         'crossStreet': 'Poblacion',
#         'lat': 7.071422086427914,
#         'lng': 125.60883522033691,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.071422086427914,
#           'lng': 125.60883522033691}],
#         'distance': 486,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Palma Gil Street (Poblacion)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b50bfb0f964a520a93027e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501ceadce4b0876f2afb9342',
#        'name': "Majid's Kebab",
#        'location': {'address': 'Rizal Street',
#         'lat': 7.067455151071585,
#         'lng': 125.6069291787609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.067455151071585,
#           'lng': 125.6069291787609}],
#         'distance': 857,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Rizal Street',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f7',
#          'name': 'Persian Restaurant',
#          'pluralName': 'Persian Restaurants',
#          'shortName': 'Persian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501ceadce4b0876f2afb9342-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '543651d7498ea6ce63a690fb',
#        'name': 'Mono Resto-Bar & After Office',
#        'location': {'address': 'The Peak Gaisano Mall Of Davao',
#         'lat': 7.077290224286048,
#         'lng': 125.61430629252014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.077290224286048,
#           'lng': 125.61430629252014}],
#         'distance': 601,
#         'cc': 'PH',
#         'country': 'Pilipinas',
#         'formattedAddress': ['The Peak Gaisano Mall Of Davao', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-543651d7498ea6ce63a690fb-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d145e28401db60c71cdd7a4',
#        'name': "Cecil's",
#        'location': {'address': 'Narra St',
#         'crossStreet': 'Sta Ana',
#         'lat': 7.0766745859744455,
#         'lng': 125.61678422579277,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0766745859744455,
#           'lng': 125.61678422579277}],
#         'distance': 653,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Narra St (Sta Ana)',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d145e28401db60c71cdd7a4-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c32c61d452620a19ca4220f',
#        'name': "Cecil's",
#        'location': {'address': 'Anda St',
#         'lat': 7.067926342561733,
#         'lng': 125.60833280752011,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.067926342561733,
#           'lng': 125.60833280752011}],
#         'distance': 703,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Anda St', '8000 Davao City', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c32c61d452620a19ca4220f-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d551ad8ba5b224bba590a14',
#        'name': 'New Asia Restaurant',
#        'location': {'address': 'Villa Abrille St.',
#         'lat': 7.07483519687107,
#         'lng': 125.61330266081505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.07483519687107,
#           'lng': 125.61330266081505}],
#         'distance': 315,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Villa Abrille St.', 'Davao City', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d551ad8ba5b224bba590a14-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0598cf29c22bbefeec5631',
#        'name': "Papa Ching's Restaurant",
#        'location': {'address': 'J. Camus Extension',
#         'lat': 7.073857881773036,
#         'lng': 125.60659819005126,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.073857881773036,
#           'lng': 125.60659819005126}],
#         'distance': 758,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['J. Camus Extension',
#          'Davao',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0598cf29c22bbefeec5631-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5232ede211d2beb08b913340',
#        'name': 'Red Corner Burger Cafe',
#        'location': {'address': 'Mabini Street',
#         'lat': 7.076785870160738,
#         'lng': 125.60643646908107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.076785870160738,
#           'lng': 125.60643646908107}],
#         'distance': 917,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Mabini Street',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5232ede211d2beb08b913340-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f6ae2c498e2e9e3811bc32',
#        'name': '7-Eleven',
#        'location': {'address': 'J Luna St',
#         'crossStreet': 'Jacinto',
#         'lat': 7.07221739365721,
#         'lng': 125.61396651746719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.07221739365721,
#           'lng': 125.61396651746719}],
#         'distance': 88,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['J Luna St (Jacinto)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f6ae2c498e2e9e3811bc32-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548edfd4498edadd0edbfb35',
#        'name': 'Huckleberry',
#        'location': {'address': 'Rizal Street',
#         'crossStreet': 'Ponciano',
#         'lat': 7.0663713948890825,
#         'lng': 125.60885002831634,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0663713948890825,
#           'lng': 125.60885002831634}],
#         'distance': 789,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'neighborhood': 'Poblacion',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Rizal Street (Ponciano)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'shortName': 'Cajun / Creole',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548edfd4498edadd0edbfb35-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a78100498e5518cfaabf16',
#        'name': '#deq',
#        'location': {'address': 'Tionko Street',
#         'crossStreet': 'Arellano Street',
#         'lat': 7.076693601956049,
#         'lng': 125.60812037299574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.076693601956049,
#           'lng': 125.60812037299574}],
#         'distance': 766,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Tionko Street (Arellano Street)',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a78100498e5518cfaabf16-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '531707d411d28424b4cd5d6c',
#        'name': 'Chixboy Grill',
#        'location': {'address': 'Tionko Avenue',
#         'lat': 7.077299447119982,
#         'lng': 125.60797840232776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.077299447119982,
#           'lng': 125.60797840232776}],
#         'distance': 825,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Tionko Avenue',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-531707d411d28424b4cd5d6c-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfb5fda2271baece242cd9a',
#        'name': 'Coffeecat',
#        'location': {'address': 'E. Jacinto Extension',
#         'crossStreet': 'Quirino Avenue',
#         'lat': 7.075906453352205,
#         'lng': 125.61141665647186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.075906453352205,
#           'lng': 125.61141665647186}],
#         'distance': 477,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['E. Jacinto Extension (Quirino Avenue)',
#          '8000 Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfb5fda2271baece242cd9a-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d576e9b36d1721e4225ebb1',
#        'name': 'National Book Store',
#        'location': {'address': 'Gaisano Mall of Davao',
#         'crossStreet': 'J P Laurel Ave',
#         'lat': 7.078057848380165,
#         'lng': 125.61333616768462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.078057848380165,
#           'lng': 125.61333616768462}],
#         'distance': 674,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Gaisano Mall of Davao (J P Laurel Ave)',
#          'Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d576e9b36d1721e4225ebb1-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fbcb0eee4b0d84e502496e6',
#        'name': 'One Fab Pooch',
#        'location': {'address': 'Tionko cor. Araullo',
#         'lat': 7.077467494587962,
#         'lng': 125.60750039171117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.077467494587962,
#           'lng': 125.60750039171117}],
#         'distance': 875,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Tionko cor. Araullo',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
# ...
#        'name': "Osvaldo's Cakes",
#        'location': {'address': 'Paseo de Legaspi, 115 Legazpi Street',
#         'lat': 7.068005098599887,
#         'lng': 125.60626554520886,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.068005098599887,
#           'lng': 125.60626554520886}],
#         'distance': 885,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Paseo de Legaspi, 115 Legazpi Street',
#          '8000 Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'shortName': 'Cupcakes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec1e276d3e3700a5c771b02-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a0a978e4b047228ae6b3ef',
#        'name': "GINO'S BOOM BURGER",
#        'location': {'address': 'Jacinto Extension',
#         'lat': 7.079015931524472,
#         'lng': 125.60830395368129,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.079015931524472,
#           'lng': 125.60830395368129}],
#         'distance': 950,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Jacinto Extension',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a0a978e4b047228ae6b3ef-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb13a650aafa4370cf6498f',
#        'name': "Gusteau's",
#        'location': {'address': 'The Peak, Gaisano Mall of Davao, JP Laurel Ave',
#         'lat': 7.077344134562469,
#         'lng': 125.61453910931031,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.077344134562469,
#           'lng': 125.61453910931031}],
#         'distance': 613,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['The Peak, Gaisano Mall of Davao, JP Laurel Ave',
#          'Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb13a650aafa4370cf6498f-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52bd03c2498e8143569e0c2a',
#        'name': "McDonald's",
#        'location': {'address': 'Bolton St',
#         'crossStreet': 'Rizal St',
#         'lat': 7.066298239305909,
#         'lng': 125.60932803676835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.066298239305909,
#           'lng': 125.60932803676835}],
#         'distance': 765,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Bolton St (Rizal St)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52bd03c2498e8143569e0c2a-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1b1cbc70d76ea8fdbe4b73',
#        'name': 'Zed Pizza',
#        'location': {'address': 'Bonifacio St',
#         'lat': 7.068601710793795,
#         'lng': 125.60834209828735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.068601710793795,
#           'lng': 125.60834209828735}],
#         'distance': 656,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Bonifacio St', 'Davao City', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1b1cbc70d76ea8fdbe4b73-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d92ed6b62ad54816b28764b',
#        'name': 'Watsons',
#        'location': {'address': 'Gaisano Mall of Davao',
#         'lat': 7.078160161544028,
#         'lng': 125.61421884159712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.078160161544028,
#           'lng': 125.61421884159712}],
#         'distance': 694,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Gaisano Mall of Davao',
#          'Davao City',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d92ed6b62ad54816b28764b-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c622e3b79d1e21e29b3d515',
#        'name': "Miko's Brew",
#        'location': {'address': 'Chavez St',
#         'crossStreet': 'Chavez Street',
#         'lat': 7.0762293838850425,
#         'lng': 125.61747337331609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0762293838850425,
#           'lng': 125.61747337331609}],
#         'distance': 666,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Chavez St (Chavez Street)',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c622e3b79d1e21e29b3d515-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6dc39e30d5b1f725e2bd42',
#        'name': 'Chickies and Patties',
#        'location': {'address': 'Magsaysay Ave',
#         'lat': 7.07372938401334,
#         'lng': 125.61449430755977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.07372938401334,
#           'lng': 125.61449430755977}],
#         'distance': 239,
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Magsaysay Ave',
#          'Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6dc39e30d5b1f725e2bd42-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e41313fb0fb1399f6e95bea',
#        'name': "Gabbie's Garden Restaurant",
#        'location': {'address': 'Vinzon St.',
#         'crossStreet': 'Bo. Obrero',
#         'lat': 7.080892392725727,
#         'lng': 125.61439399171394,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.080892392725727,
#           'lng': 125.61439399171394}],
#         'distance': 998,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Vinzon St. (Bo. Obrero)',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e41313fb0fb1399f6e95bea-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a78dc6e4b078584fb5883f',
#        'name': "Sale'ss Bar Tekanplor",
#        'location': {'lat': 7.0751615740304254,
#         'lng': 125.61978360657905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.0751615740304254,
#           'lng': 125.61978360657905}],
#         'distance': 807,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Lungsod ng Dabaw', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a78dc6e4b078584fb5883f-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502b5e0ae4b03fdb3cc02ed2',
#        'name': 'Blueberry Tourist Hotel',
#        'location': {'address': 'Jacinto Extension',
#         'lat': 7.07919395705648,
#         'lng': 125.60825005368629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.07919395705648,
#           'lng': 125.60825005368629}],
#         'distance': 969,
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Jacinto Extension',
#          'Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502b5e0ae4b03fdb3cc02ed2-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9ba9e5c18aa35d7bff72ff',
#        'name': 'Royal Breadhaus',
#        'location': {'lat': 7.079411148502256,
#         'lng': 125.60809457443061,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.079411148502256,
#           'lng': 125.60809457443061}],
#         'distance': 999,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['8000 Lungsod ng Dabaw', 'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'shortName': 'Cupcakes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9ba9e5c18aa35d7bff72ff-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eab7e56d3e3846cbd1de5d0',
#        'name': 'Gaisano Mall Cinema 4',
#        'location': {'address': '4/F, Gaisano Mall of Davao, J P Laurel Ave',
#         'lat': 7.077697441796613,
#         'lng': 125.61357525174506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.077697441796613,
#           'lng': 125.61357525174506}],
#         'distance': 635,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Davao City',
#         'state': 'Davao del Sur',
#         'country': 'Pilipinas',
#         'formattedAddress': ['4/F, Gaisano Mall of Davao, J P Laurel Ave',
#          '8000 Davao City',
#          'Davao del Sur',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eab7e56d3e3846cbd1de5d0-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '510e4bb8e4b0428edd110dde',
#        'name': 'BBQ Bob',
#        'location': {'address': 'Andres Bonifacio St',
#         'crossStreet': 'C. Bangoy St',
#         'lat': 7.067945535052817,
#         'lng': 125.60908153477972,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 7.067945535052817,
#           'lng': 125.60908153477972}],
#         'distance': 640,
#         'postalCode': '8000',
#         'cc': 'PH',
#         'city': 'Lungsod ng Dabaw',
#         'country': 'Pilipinas',
#         'formattedAddress': ['Andres Bonifacio St (C. Bangoy St)',
#          '8000 Lungsod ng Dabaw',
#          'Pilipinas']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-510e4bb8e4b0428edd110dde-99'}]}]}}

# %% [markdown]
# ##### Just a little reminder
#
# results['response']['groups'][0]['items'][0]['venue']['categories'][0]['name']

# %%
results1['response']['groups']
# Out:
# [{'type': 'Recommended Places',
#   'name': 'recommended',
#   'items': [{'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b9dd234f964a5200dbf36e3',
#      'name': 'Marco Polo Davao',
#      'location': {'address': 'Roxas Ave',
#       'crossStreet': 'C M Recto Ave',
#       'lat': 7.0720768904109725,
#       'lng': 125.61134576797485,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0720768904109725,
#         'lng': 125.61134576797485}],
#       'distance': 205,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'neighborhood': 'Poblacion',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Roxas Ave (C M Recto Ave)',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1fa931735',
#        'name': 'Hotel',
#        'pluralName': 'Hotels',
#        'shortName': 'Hotel',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b9dd234f964a5200dbf36e3-0'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4cfe012bee9cb60c15629dad',
#      'name': 'Harley Boulevard Motor Cafe',
#      'location': {'address': 'J. Luna St.',
#       'crossStreet': 'btwn J. Dela Cruz & Guerrero St.',
#       'lat': 7.072273280161847,
#       'lng': 125.61560030988757,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.072273280161847,
#         'lng': 125.61560030988757}],
#       'distance': 266,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['J. Luna St. (btwn J. Dela Cruz & Guerrero St.)',
#        '8000 Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d147941735',
#        'name': 'Diner',
#        'pluralName': 'Diners',
#        'shortName': 'Diner',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4cfe012bee9cb60c15629dad-1'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4f273367e4b0d609c9494240',
#      'name': 'Cafe Marco',
#      'location': {'address': 'Marco Polo Hotel',
#       'crossStreet': 'C. M. Recto St.,',
#       'lat': 7.072105041242055,
#       'lng': 125.61186757699707,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.072105041242055,
#         'lng': 125.61186757699707}],
#       'distance': 147,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'neighborhood': 'Poblacion',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Marco Polo Hotel (C. M. Recto St.,)',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d143941735',
#        'name': 'Breakfast Spot',
#        'pluralName': 'Breakfast Spots',
#        'shortName': 'Breakfast',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4f273367e4b0d609c9494240-2'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4e6cb742b0fba3f50e6a9a51',
#      'name': 'Roxas Night Market',
#      'location': {'address': 'Roxas Ave',
#       'lat': 7.070947791509277,
#       'lng': 125.61330966991832,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.070947791509277,
#         'lng': 125.61330966991832}],
#       'distance': 117,
#       'cc': 'PH',
#       'neighborhood': 'Poblacion',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Roxas Ave', 'Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1f7941735',
#        'name': 'Flea Market',
#        'pluralName': 'Flea Markets',
#        'shortName': 'Flea Market',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4e6cb742b0fba3f50e6a9a51-3'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ef47203722e31c647a21e53',
#      'name': 'Sencha',
#      'location': {'address': 'Magsaysay Ave.',
#       'lat': 7.073686159227526,
#       'lng': 125.61428990584103,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.073686159227526,
#         'lng': 125.61428990584103}],
#       'distance': 222,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Magsaysay Ave.', 'Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ef47203722e31c647a21e53-4'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '500a71a5ebca2b447ac984cf',
#      'name': 'Happy Lemon',
#      'location': {'address': 'The Peak, Gaisano Mall of Davao, J P Laurel Ave, Bajada',
#       'lat': 7.07711049052085,
#       'lng': 125.61441600336288,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.07711049052085,
#         'lng': 125.61441600336288}],
#       'distance': 584,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['The Peak, Gaisano Mall of Davao, J P Laurel Ave, Bajada',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#        'name': 'Bubble Tea Shop',
#        'pluralName': 'Bubble Tea Shops',
#        'shortName': 'Bubble Tea',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-500a71a5ebca2b447ac984cf-5'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4cc7d77f3c40a35d554b712e',
#      'name': 'Chippens',
#      'location': {'address': 'Roxas',
#       'lat': 7.070115510709253,
#       'lng': 125.61408325765399,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.070115510709253,
#         'lng': 125.61408325765399}],
#       'distance': 231,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Roxas', 'Davao City', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d14e941735',
#        'name': 'American Restaurant',
#        'pluralName': 'American Restaurants',
#        'shortName': 'American',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4cc7d77f3c40a35d554b712e-6'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c8b06a91797236a15a66788',
#      'name': 'Glamour Crab Buffet',
#      'location': {'address': 'Gomez',
#       'crossStreet': 'Roxas',
#       'lat': 7.0693528393314,
#       'lng': 125.61329037497404,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0693528393314,
#         'lng': 125.61329037497404}],
#       'distance': 294,
#       'cc': 'PH',
#       'city': 'Davao',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Gomez (Roxas)', 'Davao', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1ce941735',
#        'name': 'Seafood Restaurant',
#        'pluralName': 'Seafood Restaurants',
#        'shortName': 'Seafood',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c8b06a91797236a15a66788-7'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4f77f307e4b07024fb0e162b',
#      'name': 'Marco Polo Poolside',
#      'location': {'crossStreet': 'at CM Recto Ave',
#       'lat': 7.072109576420102,
#       'lng': 125.61103487719521,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.072109576420102,
#         'lng': 125.61103487719521}],
#       'distance': 239,
#       'cc': 'PH',
#       'country': 'Pilipinas',
#       'formattedAddress': ['at CM Recto Ave', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d132951735',
#        'name': 'Hotel Pool',
#        'pluralName': 'Hotel Pools',
#        'shortName': 'Pool',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4f77f307e4b07024fb0e162b-8'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4fdf2aede4b082d077339a3b',
#      'name': 'Mic1 KTV',
#      'location': {'address': 'J.P. Laurel Ave.',
#       'lat': 7.075983735247778,
#       'lng': 125.61316326270588,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.075983735247778,
#         'lng': 125.61316326270588}],
#       'distance': 443,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['J.P. Laurel Ave.',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d120941735',
#        'name': 'Karaoke Bar',
#        'pluralName': 'Karaoke Bars',
#        'shortName': 'Karaoke',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4fdf2aede4b082d077339a3b-9'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d0cdc77257d6dcb886d9867',
#      'name': 'Ice Giants',
#      'location': {'address': 'Santa Ana Ave.',
#       'crossStreet': 'at J.P. Laurel Avenue',
#       'lat': 7.076652835889294,
#       'lng': 125.61458877439733,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.076652835889294,
#         'lng': 125.61458877439733}],
#       'distance': 540,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Santa Ana Ave. (at J.P. Laurel Avenue)',
#        '8000 Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1d0941735',
#        'name': 'Dessert Shop',
#        'pluralName': 'Dessert Shops',
#        'shortName': 'Desserts',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d0cdc77257d6dcb886d9867-10'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '5146abb3e4b0251c39b3eb28',
#      'name': 'My Skin Essentials',
#      'location': {'address': 'Jacinto Street',
#       'lat': 7.070519736022691,
#       'lng': 125.61540659316996,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.070519736022691,
#         'lng': 125.61540659316996}],
#       'distance': 294,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Jacinto Street', 'Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d10c951735',
#        'name': 'Cosmetics Shop',
#        'pluralName': 'Cosmetics Shops',
#        'shortName': 'Cosmetics',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-5146abb3e4b0251c39b3eb28-11'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c658ab119f3c9b6ae5f9dff',
#      'name': 'Pacific Spa',
#      'location': {'address': 'C.M. Recto Ave,',
#       'crossStreet': 'Roxas St.',
#       'lat': 7.071725076144522,
#       'lng': 125.61147341045125,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.071725076144522,
#         'lng': 125.61147341045125}],
#       'distance': 193,
#       'cc': 'PH',
#       'country': 'Pilipinas',
#       'formattedAddress': ['C.M. Recto Ave, (Roxas St.)', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1ed941735',
#        'name': 'Spa',
#        'pluralName': 'Spas',
#        'shortName': 'Spa',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c658ab119f3c9b6ae5f9dff-12'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '508806a8e4b0b793e370fe3d',
#      'name': 'Dox Hub',
#      'location': {'address': 'Juan dela Cruz Street',
#       'lat': 7.0717783,
#       'lng': 125.61549,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0717783,
#         'lng': 125.61549}],
#       'distance': 254,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'neighborhood': 'Poblacion',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Juan dela Cruz Street',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d117941735',
#        'name': 'Beer Garden',
#        'pluralName': 'Beer Gardens',
#        'shortName': 'Beer Garden',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-508806a8e4b0b793e370fe3d-13'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '55c77c08498e6a7f02ebdc2c',
#      'name': 'Coffee Grounds',
#      'location': {'address': 'Roxas Extension, Golden Lion Dormitel',
#       'lat': 7.066257411098499,
#       'lng': 125.61701379873908,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.066257411098499,
#         'lng': 125.61701379873908}],
#       'distance': 765,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'neighborhood': 'Barangay 31',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Roxas Extension, Golden Lion Dormitel',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-55c77c08498e6a7f02ebdc2c-14'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '5459fdb9498eed3c99a0ce85',
#      'name': 'Caffè Antoccino',
#      'location': {'address': '59 Guerrero',
#       'lat': 7.072803705714685,
#       'lng': 125.6166128156653,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.072803705714685,
#         'lng': 125.6166128156653}],
#       'distance': 387,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['59 Guerrero',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-5459fdb9498eed3c99a0ce85-15'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '526bca30498e46e8215a27c2',
#      'name': 'Mabini BBQ Haus',
#      'location': {'address': 'Mabini Street',
#       'lat': 7.068491741156339,
#       'lng': 125.61332684165363,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.068491741156339,
#         'lng': 125.61332684165363}],
#       'distance': 390,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Mabini Street',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1df931735',
#        'name': 'BBQ Joint',
#        'pluralName': 'BBQ Joints',
#        'shortName': 'BBQ',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-526bca30498e46e8215a27c2-16'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4f54a513e4b0bf6b5f897b90',
#      'name': 'Pastil BBQ Sa Ponce',
#      'location': {'address': 'Ponce St.',
#       'crossStreet': 'Juan Dela Cruz St.',
#       'lat': 7.070817286550607,
#       'lng': 125.61557028107534,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.070817286550607,
#         'lng': 125.61557028107534}],
#       'distance': 293,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Ponce St. (Juan Dela Cruz St.)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1df931735',
#        'name': 'BBQ Joint',
#        'pluralName': 'BBQ Joints',
#        'shortName': 'BBQ',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4f54a513e4b0bf6b5f897b90-17'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ccc054b54f0b1f7303713ca',
#      'name': 'Tan-Ton Thai Massage',
#      'location': {'address': 'JP Laurel',
#       'lat': 7.075278670379594,
#       'lng': 125.61286114304968,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.075278670379594,
#         'lng': 125.61286114304968}],
#       'distance': 366,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['JP Laurel', 'Davao City', 'Pilipinas']},
#      'categories': [{'id': '4d1cf8421a97d635ce361c31',
#        'name': 'Tanning Salon',
#        'pluralName': 'Tanning Salons',
#        'shortName': 'Tanning Salon',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tanning_salon_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ccc054b54f0b1f7303713ca-18'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4f896a5ae4b0c71a71b10b41',
#      'name': 'Cafe Frances',
#      'location': {'address': 'Ground Floor The Pinnacle Hotel and Suites, Sta. Ana Avenue',
#       'lat': 7.076222182824272,
#       'lng': 125.61524152225961,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.076222182824272,
#         'lng': 125.61524152225961}],
#       'distance': 521,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Ground Floor The Pinnacle Hotel and Suites, Sta. Ana Avenue',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4f896a5ae4b0c71a71b10b41-19'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d08bcbe4adb37041274fe54',
#      'name': 'Pancake House',
#      'location': {'address': 'Gaisano Mall, J P Laurel Ave',
#       'lat': 7.078162171699689,
#       'lng': 125.6142282716855,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.078162171699689,
#         'lng': 125.6142282716855}],
#       'distance': 695,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Gaisano Mall, J P Laurel Ave',
#        '8000 Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d14e941735',
#        'name': 'American Restaurant',
#        'pluralName': 'American Restaurants',
#        'shortName': 'American',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d08bcbe4adb37041274fe54-20'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4bf0d3dda09076b0d9c329d4',
#      'name': "Davao Dencia's Restaurant, Inc.",
#      'location': {'address': 'General Luna St.',
#       'crossStreet': 'cor. Ilustre St.',
#       'lat': 7.069639875928841,
#       'lng': 125.60669779268378,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.069639875928841,
#         'lng': 125.60669779268378}],
#       'distance': 764,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['General Luna St. (cor. Ilustre St.)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d145941735',
#        'name': 'Chinese Restaurant',
#        'pluralName': 'Chinese Restaurants',
#        'shortName': 'Chinese',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4bf0d3dda09076b0d9c329d4-21'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c8b91881eafb1f783ab8435',
#      'name': 'Casa De Amigos',
#      'location': {'lat': 7.071372969980646,
#       'lng': 125.61107781180834,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.071372969980646,
#         'lng': 125.61107781180834}],
#       'distance': 244,
#       'cc': 'PH',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d116941735',
#        'name': 'Bar',
#        'pluralName': 'Bars',
#        'shortName': 'Bar',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c8b91881eafb1f783ab8435-22'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '583cbc17561ded188294071d',
#      'name': 'Bondi&Bourke',
#      'location': {'address': '115 P Pelayo St',
#       'lat': 7.067949571237114,
#       'lng': 125.60628029451563,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.067949571237114,
#         'lng': 125.60628029451563}],
#       'distance': 887,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['115 P Pelayo St',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d169941735',
#        'name': 'Australian Restaurant',
#        'pluralName': 'Australian Restaurants',
#        'shortName': 'Australian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-583cbc17561ded188294071d-23'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4e4520741838e44e899530f5',
#      'name': 'Thai Boran Massage',
#      'location': {'address': 'Camus St',
#       'crossStreet': 'Pardo de Tavera St.',
#       'lat': 7.072450813722844,
#       'lng': 125.6070127765347,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.072450813722844,
#         'lng': 125.6070127765347}],
#       'distance': 685,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Camus St (Pardo de Tavera St.)',
#        'Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1ed941735',
#        'name': 'Spa',
#        'pluralName': 'Spas',
#        'shortName': 'Spa',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4e4520741838e44e899530f5-24'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d3a779fbf6d54811597cde1',
#      'name': 'Metro Card Club Davao',
#      'location': {'address': 'CVA Building, Quirino Street',
#       'lat': 7.075584510707617,
#       'lng': 125.6118790174616,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.075584510707617,
#         'lng': 125.6118790174616}],
#       'distance': 424,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['CVA Building, Quirino Street',
#        'Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d17c941735',
#        'name': 'Casino',
#        'pluralName': 'Casinos',
#        'shortName': 'Casino',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d3a779fbf6d54811597cde1-25'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b50bfb0f964a520a93027e3',
#      'name': "People's Park",
#      'location': {'address': 'Palma Gil Street',
#       'crossStreet': 'Poblacion',
#       'lat': 7.071422086427914,
#       'lng': 125.60883522033691,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.071422086427914,
#         'lng': 125.60883522033691}],
#       'distance': 486,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Palma Gil Street (Poblacion)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d163941735',
#        'name': 'Park',
#        'pluralName': 'Parks',
#        'shortName': 'Park',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b50bfb0f964a520a93027e3-26'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '501ceadce4b0876f2afb9342',
#      'name': "Majid's Kebab",
#      'location': {'address': 'Rizal Street',
#       'lat': 7.067455151071585,
#       'lng': 125.6069291787609,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.067455151071585,
#         'lng': 125.6069291787609}],
#       'distance': 857,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Rizal Street',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '52e81612bcbc57f1066b79f7',
#        'name': 'Persian Restaurant',
#        'pluralName': 'Persian Restaurants',
#        'shortName': 'Persian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-501ceadce4b0876f2afb9342-27'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '543651d7498ea6ce63a690fb',
#      'name': 'Mono Resto-Bar & After Office',
#      'location': {'address': 'The Peak Gaisano Mall Of Davao',
#       'lat': 7.077290224286048,
#       'lng': 125.61430629252014,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.077290224286048,
#         'lng': 125.61430629252014}],
#       'distance': 601,
#       'cc': 'PH',
#       'country': 'Pilipinas',
#       'formattedAddress': ['The Peak Gaisano Mall Of Davao', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d121941735',
#        'name': 'Lounge',
#        'pluralName': 'Lounges',
#        'shortName': 'Lounge',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-543651d7498ea6ce63a690fb-28'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d145e28401db60c71cdd7a4',
#      'name': "Cecil's",
#      'location': {'address': 'Narra St',
#       'crossStreet': 'Sta Ana',
#       'lat': 7.0766745859744455,
#       'lng': 125.61678422579277,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0766745859744455,
#         'lng': 125.61678422579277}],
#       'distance': 653,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Narra St (Sta Ana)',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1c7941735',
#        'name': 'Snack Place',
#        'pluralName': 'Snack Places',
#        'shortName': 'Snacks',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d145e28401db60c71cdd7a4-29'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c32c61d452620a19ca4220f',
#      'name': "Cecil's",
#      'location': {'address': 'Anda St',
#       'lat': 7.067926342561733,
#       'lng': 125.60833280752011,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.067926342561733,
#         'lng': 125.60833280752011}],
#       'distance': 703,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Anda St', '8000 Davao City', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1c7941735',
#        'name': 'Snack Place',
#        'pluralName': 'Snack Places',
#        'shortName': 'Snacks',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c32c61d452620a19ca4220f-30'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d551ad8ba5b224bba590a14',
#      'name': 'New Asia Restaurant',
#      'location': {'address': 'Villa Abrille St.',
#       'lat': 7.07483519687107,
#       'lng': 125.61330266081505,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.07483519687107,
#         'lng': 125.61330266081505}],
#       'distance': 315,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Villa Abrille St.', 'Davao City', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d145941735',
#        'name': 'Chinese Restaurant',
#        'pluralName': 'Chinese Restaurants',
#        'shortName': 'Chinese',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d551ad8ba5b224bba590a14-31'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4f0598cf29c22bbefeec5631',
#      'name': "Papa Ching's Restaurant",
#      'location': {'address': 'J. Camus Extension',
#       'lat': 7.073857881773036,
#       'lng': 125.60659819005126,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.073857881773036,
#         'lng': 125.60659819005126}],
#       'distance': 758,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['J. Camus Extension',
#        'Davao',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#        'name': 'Fried Chicken Joint',
#        'pluralName': 'Fried Chicken Joints',
#        'shortName': 'Fried Chicken',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4f0598cf29c22bbefeec5631-32'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '5232ede211d2beb08b913340',
#      'name': 'Red Corner Burger Cafe',
#      'location': {'address': 'Mabini Street',
#       'lat': 7.076785870160738,
#       'lng': 125.60643646908107,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.076785870160738,
#         'lng': 125.60643646908107}],
#       'distance': 917,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Mabini Street', 'Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16c941735',
#        'name': 'Burger Joint',
#        'pluralName': 'Burger Joints',
#        'shortName': 'Burgers',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-5232ede211d2beb08b913340-33'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '55f6ae2c498e2e9e3811bc32',
#      'name': '7-Eleven',
#      'location': {'address': 'J Luna St',
#       'crossStreet': 'Jacinto',
#       'lat': 7.07221739365721,
#       'lng': 125.61396651746719,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.07221739365721,
#         'lng': 125.61396651746719}],
#       'distance': 88,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['J Luna St (Jacinto)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4d954b0ea243a5684a65b473',
#        'name': 'Convenience Store',
#        'pluralName': 'Convenience Stores',
#        'shortName': 'Convenience Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-55f6ae2c498e2e9e3811bc32-34'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '548edfd4498edadd0edbfb35',
#      'name': 'Huckleberry',
#      'location': {'address': 'Rizal Street',
#       'crossStreet': 'Ponciano',
#       'lat': 7.0663713948890825,
#       'lng': 125.60885002831634,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0663713948890825,
#         'lng': 125.60885002831634}],
#       'distance': 789,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'neighborhood': 'Poblacion',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Rizal Street (Ponciano)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d17a941735',
#        'name': 'Cajun / Creole Restaurant',
#        'pluralName': 'Cajun / Creole Restaurants',
#        'shortName': 'Cajun / Creole',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-548edfd4498edadd0edbfb35-35'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '56a78100498e5518cfaabf16',
#      'name': '#deq',
#      'location': {'address': 'Tionko Street',
#       'crossStreet': 'Arellano Street',
#       'lat': 7.076693601956049,
#       'lng': 125.60812037299574,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.076693601956049,
#         'lng': 125.60812037299574}],
#       'distance': 766,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Tionko Street (Arellano Street)',
#        'Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d121941735',
#        'name': 'Lounge',
#        'pluralName': 'Lounges',
#        'shortName': 'Lounge',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-56a78100498e5518cfaabf16-36'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '531707d411d28424b4cd5d6c',
#      'name': 'Chixboy Grill',
#      'location': {'address': 'Tionko Avenue',
#       'lat': 7.077299447119982,
#       'lng': 125.60797840232776,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.077299447119982,
#         'lng': 125.60797840232776}],
#       'distance': 825,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Tionko Avenue',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1df931735',
#        'name': 'BBQ Joint',
#        'pluralName': 'BBQ Joints',
#        'shortName': 'BBQ',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-531707d411d28424b4cd5d6c-37'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4dfb5fda2271baece242cd9a',
#      'name': 'Coffeecat',
#      'location': {'address': 'E. Jacinto Extension',
#       'crossStreet': 'Quirino Avenue',
#       'lat': 7.075906453352205,
#       'lng': 125.61141665647186,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.075906453352205,
#         'lng': 125.61141665647186}],
#       'distance': 477,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['E. Jacinto Extension (Quirino Avenue)',
#        '8000 Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4dfb5fda2271baece242cd9a-38'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d576e9b36d1721e4225ebb1',
#      'name': 'National Book Store',
#      'location': {'address': 'Gaisano Mall of Davao',
#       'crossStreet': 'J P Laurel Ave',
#       'lat': 7.078057848380165,
#       'lng': 125.61333616768462,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.078057848380165,
#         'lng': 125.61333616768462}],
#       'distance': 674,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Gaisano Mall of Davao (J P Laurel Ave)',
#        'Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d114951735',
#        'name': 'Bookstore',
#        'pluralName': 'Bookstores',
#        'shortName': 'Bookstore',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d576e9b36d1721e4225ebb1-39'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4fbcb0eee4b0d84e502496e6',
#      'name': 'One Fab Pooch',
#      'location': {'address': 'Tionko cor. Araullo',
#       'lat': 7.077467494587962,
#       'lng': 125.60750039171117,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.077467494587962,
#         'lng': 125.60750039171117}],
#       'distance': 875,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Tionko cor. Araullo',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d100951735',
#        'name': 'Pet Store',
#        'pluralName': 'Pet Stores',
#        'shortName': 'Pet Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4fbcb0eee4b0d84e502496e6-40'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d1683b6401db60c5514e6a4',
#      'name': 'Taps',
#      'location': {'address': 'Governor duterte st',
#       'lat': 7.0697345398275475,
#       'lng': 125.60512778080181,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0697345398275475,
#         'lng': 125.60512778080181}],
#       'distance': 926,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Governor duterte st', 'Davao City', 'Pilipinas']},
#      'categories': [{'id': '4eb1bd1c3b7b55596b4a748f',
#        'name': 'Filipino Restaurant',
#        'pluralName': 'Filipino Restaurants',
#        'shortName': 'Filipino',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/filipino_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d1683b6401db60c5514e6a4-41'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '51ade0c6498e9d44001011f2',
#      'name': 'Tapas y Bebidas',
#      'location': {'address': 'Pelayo St.',
#       'lat': 7.068548593190691,
#       'lng': 125.60677545698802,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.068548593190691,
#         'lng': 125.60677545698802}],
#       'distance': 807,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Pelayo St.',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d116941735',
#        'name': 'Bar',
#        'pluralName': 'Bars',
#        'shortName': 'Bar',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-51ade0c6498e9d44001011f2-42'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4fa70eefe4b089a95b869a89',
#      'name': 'ALU Hotel',
#      'location': {'address': 'M. Roxas Avenue corner Padre Faure St',
#       'crossStreet': 'Padre Gomez Street',
#       'lat': 7.06892863871707,
#       'lng': 125.61448653447117,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.06892863871707,
#         'lng': 125.61448653447117}],
#       'distance': 370,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
# ...
#         'lng': 125.61415488613329}],
#       'distance': 707,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['L/GF Gaisano Mall of Davao, Bajada',
#        'Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16a941735',
#        'name': 'Bakery',
#        'pluralName': 'Bakeries',
#        'shortName': 'Bakery',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-552dd307498ea1781452fcd5-85'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ec1e276d3e3700a5c771b02',
#      'name': "Osvaldo's Cakes",
#      'location': {'address': 'Paseo de Legaspi, 115 Legazpi Street',
#       'lat': 7.068005098599887,
#       'lng': 125.60626554520886,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.068005098599887,
#         'lng': 125.60626554520886}],
#       'distance': 885,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Paseo de Legaspi, 115 Legazpi Street',
#        '8000 Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1bc941735',
#        'name': 'Cupcake Shop',
#        'pluralName': 'Cupcake Shops',
#        'shortName': 'Cupcakes',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ec1e276d3e3700a5c771b02-86'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '50a0a978e4b047228ae6b3ef',
#      'name': "GINO'S BOOM BURGER",
#      'location': {'address': 'Jacinto Extension',
#       'lat': 7.079015931524472,
#       'lng': 125.60830395368129,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.079015931524472,
#         'lng': 125.60830395368129}],
#       'distance': 950,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Jacinto Extension',
#        'Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16c941735',
#        'name': 'Burger Joint',
#        'pluralName': 'Burger Joints',
#        'shortName': 'Burgers',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-50a0a978e4b047228ae6b3ef-87'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4eb13a650aafa4370cf6498f',
#      'name': "Gusteau's",
#      'location': {'address': 'The Peak, Gaisano Mall of Davao, JP Laurel Ave',
#       'lat': 7.077344134562469,
#       'lng': 125.61453910931031,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.077344134562469,
#         'lng': 125.61453910931031}],
#       'distance': 613,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['The Peak, Gaisano Mall of Davao, JP Laurel Ave',
#        'Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1ce941735',
#        'name': 'Seafood Restaurant',
#        'pluralName': 'Seafood Restaurants',
#        'shortName': 'Seafood',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4eb13a650aafa4370cf6498f-88'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '52bd03c2498e8143569e0c2a',
#      'name': "McDonald's",
#      'location': {'address': 'Bolton St',
#       'crossStreet': 'Rizal St',
#       'lat': 7.066298239305909,
#       'lng': 125.60932803676835,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.066298239305909,
#         'lng': 125.60932803676835}],
#       'distance': 765,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Bolton St (Rizal St)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d16e941735',
#        'name': 'Fast Food Restaurant',
#        'pluralName': 'Fast Food Restaurants',
#        'shortName': 'Fast Food',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-52bd03c2498e8143569e0c2a-89'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d1b1cbc70d76ea8fdbe4b73',
#      'name': 'Zed Pizza',
#      'location': {'address': 'Bonifacio St',
#       'lat': 7.068601710793795,
#       'lng': 125.60834209828735,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.068601710793795,
#         'lng': 125.60834209828735}],
#       'distance': 656,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Bonifacio St', 'Davao City', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1ca941735',
#        'name': 'Pizza Place',
#        'pluralName': 'Pizza Places',
#        'shortName': 'Pizza',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d1b1cbc70d76ea8fdbe4b73-90'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d92ed6b62ad54816b28764b',
#      'name': 'Watsons',
#      'location': {'address': 'Gaisano Mall of Davao',
#       'lat': 7.078160161544028,
#       'lng': 125.61421884159712,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.078160161544028,
#         'lng': 125.61421884159712}],
#       'distance': 694,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Gaisano Mall of Davao',
#        'Davao City',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d10c951735',
#        'name': 'Cosmetics Shop',
#        'pluralName': 'Cosmetics Shops',
#        'shortName': 'Cosmetics',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d92ed6b62ad54816b28764b-91'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c622e3b79d1e21e29b3d515',
#      'name': "Miko's Brew",
#      'location': {'address': 'Chavez St',
#       'crossStreet': 'Chavez Street',
#       'lat': 7.0762293838850425,
#       'lng': 125.61747337331609,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0762293838850425,
#         'lng': 125.61747337331609}],
#       'distance': 666,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Chavez St (Chavez Street)',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c622e3b79d1e21e29b3d515-92'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d6dc39e30d5b1f725e2bd42',
#      'name': 'Chickies and Patties',
#      'location': {'address': 'Magsaysay Ave',
#       'lat': 7.07372938401334,
#       'lng': 125.61449430755977,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.07372938401334,
#         'lng': 125.61449430755977}],
#       'distance': 239,
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Magsaysay Ave',
#        'Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#        'name': 'Fried Chicken Joint',
#        'pluralName': 'Fried Chicken Joints',
#        'shortName': 'Fried Chicken',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d6dc39e30d5b1f725e2bd42-93'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4e41313fb0fb1399f6e95bea',
#      'name': "Gabbie's Garden Restaurant",
#      'location': {'address': 'Vinzon St.',
#       'crossStreet': 'Bo. Obrero',
#       'lat': 7.080892392725727,
#       'lng': 125.61439399171394,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.080892392725727,
#         'lng': 125.61439399171394}],
#       'distance': 998,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Vinzon St. (Bo. Obrero)',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d117941735',
#        'name': 'Beer Garden',
#        'pluralName': 'Beer Gardens',
#        'shortName': 'Beer Garden',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4e41313fb0fb1399f6e95bea-94'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '50a78dc6e4b078584fb5883f',
#      'name': "Sale'ss Bar Tekanplor",
#      'location': {'lat': 7.0751615740304254,
#       'lng': 125.61978360657905,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.0751615740304254,
#         'lng': 125.61978360657905}],
#       'distance': 807,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d116941735',
#        'name': 'Bar',
#        'pluralName': 'Bars',
#        'shortName': 'Bar',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-50a78dc6e4b078584fb5883f-95'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '502b5e0ae4b03fdb3cc02ed2',
#      'name': 'Blueberry Tourist Hotel',
#      'location': {'address': 'Jacinto Extension',
#       'lat': 7.07919395705648,
#       'lng': 125.60825005368629,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.07919395705648,
#         'lng': 125.60825005368629}],
#       'distance': 969,
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Jacinto Extension',
#        'Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1fa931735',
#        'name': 'Hotel',
#        'pluralName': 'Hotels',
#        'shortName': 'Hotel',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-502b5e0ae4b03fdb3cc02ed2-96'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d9ba9e5c18aa35d7bff72ff',
#      'name': 'Royal Breadhaus',
#      'location': {'lat': 7.079411148502256,
#       'lng': 125.60809457443061,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.079411148502256,
#         'lng': 125.60809457443061}],
#       'distance': 999,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['8000 Lungsod ng Dabaw', 'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1bc941735',
#        'name': 'Cupcake Shop',
#        'pluralName': 'Cupcake Shops',
#        'shortName': 'Cupcakes',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d9ba9e5c18aa35d7bff72ff-97'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4eab7e56d3e3846cbd1de5d0',
#      'name': 'Gaisano Mall Cinema 4',
#      'location': {'address': '4/F, Gaisano Mall of Davao, J P Laurel Ave',
#       'lat': 7.077697441796613,
#       'lng': 125.61357525174506,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.077697441796613,
#         'lng': 125.61357525174506}],
#       'distance': 635,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Davao City',
#       'state': 'Davao del Sur',
#       'country': 'Pilipinas',
#       'formattedAddress': ['4/F, Gaisano Mall of Davao, J P Laurel Ave',
#        '8000 Davao City',
#        'Davao del Sur',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d17f941735',
#        'name': 'Movie Theater',
#        'pluralName': 'Movie Theaters',
#        'shortName': 'Movie Theater',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4eab7e56d3e3846cbd1de5d0-98'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '510e4bb8e4b0428edd110dde',
#      'name': 'BBQ Bob',
#      'location': {'address': 'Andres Bonifacio St',
#       'crossStreet': 'C. Bangoy St',
#       'lat': 7.067945535052817,
#       'lng': 125.60908153477972,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 7.067945535052817,
#         'lng': 125.60908153477972}],
#       'distance': 640,
#       'postalCode': '8000',
#       'cc': 'PH',
#       'city': 'Lungsod ng Dabaw',
#       'country': 'Pilipinas',
#       'formattedAddress': ['Andres Bonifacio St (C. Bangoy St)',
#        '8000 Lungsod ng Dabaw',
#        'Pilipinas']},
#      'categories': [{'id': '4bf58dd8d48988d1df931735',
#        'name': 'BBQ Joint',
#        'pluralName': 'BBQ Joints',
#        'shortName': 'BBQ',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-510e4bb8e4b0428edd110dde-99'}]}]

# %%
venuen = []
venuelat = []
venuelong = []
venuecat = []
for x in results1['response']['groups'][0]['items']:
    name = x['venue']['name']
    lat = x['venue']['location']['lat']
    long = x['venue']['location']['lng']
    catg = x['venue']['categories'][0]['name']
    if 'Hotel' in catg:
        pass
    elif 'Spa' in catg:
        pass
    else:
        venuen.append(name)
        venuelat.append(lat)
        venuelong.append(long)
        venuecat.append(catg)

# %% [markdown]
#     name = x['items'][0]['venue']['name']
#     lat = x['items'][0]['venue']['location']['lat']
#     long = x['items'][0]['venue']['location']['lng']
#     catg = x['items'][0]['venue']['categories'][0]['name']
#     venuen.append(name)
#     venuelat.append(lat)
#     venuelong.append(long)
#     venuecat.append(catg)

# %%
venues = pd.DataFrame()
venues['Name'] = venuen
venues['Category'] = venuecat
venues['Latitude'] = venuelat
venues['Longitude'] = venuelong

# %%
venues.head()
# Out:
#                           Name         Category  Latitude   Longitude
# 0  Harley Boulevard Motor Cafe            Diner  7.072273  125.615600
# 1                   Cafe Marco   Breakfast Spot  7.072105  125.611868
# 2           Roxas Night Market      Flea Market  7.070948  125.613310
# 3                       Sencha             Café  7.073686  125.614290
# 4                  Happy Lemon  Bubble Tea Shop  7.077110  125.614416

# %% [markdown]
# ## Display it on the map

# %%
# create map
map_davao= folium.Map(location=[lat1, long1], zoom_start=15)

for lat, lon, category, name in zip(schools['Latitude'],schools['Longitude'],schools['Category'],schools['Name']):
    label = folium.Popup(name +' '+ category, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=8,
        popup=label,
        color = 'orange',
        fill=True,
        fill_opacity=0.7).add_to(map_davao)
    
for lat, lon, category, name in zip(venues['Latitude'],venues['Longitude'],venues['Category'],venues['Name']):
    if 'Hotel' in category:
        pass
    elif 'Spa' in category:
        pass
    elif 'Bar' in category:
        label = folium.Popup(name +' '+ category, parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=8,
            popup=label,
            color = 'black',
            fill=True,
            fill_opacity=0.7).add_to(map_davao)
        
    elif 'Convenience' in category:
        label = folium.Popup(name +' '+ category, parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=8,
            popup=label,
            color = 'red',
            fill=True,
            fill_opacity=0.7).add_to(map_davao)
    else:
        label = folium.Popup(name +' '+ category, parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=8,
            popup=label,
            color = 'blue',
            fill=True,
            fill_opacity=0.7).add_to(map_davao)
       
map_davao
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_11d9ca21588a47f99580f1b590036e75%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_11d9ca21588a47f99580f1b590036e75%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_11d9ca21588a47f99580f1b590036e75%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_11d9ca21588a47f99580f1b590036e75%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B7.076786994934082%2C%20125.61659240722656%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # Clustering

# %% [markdown]
# ### Venue Cluster

# %%
venues.head()
# Out:
#                           Name         Category  Latitude   Longitude
# 0  Harley Boulevard Motor Cafe            Diner  7.072273  125.615600
# 1                   Cafe Marco   Breakfast Spot  7.072105  125.611868
# 2           Roxas Night Market      Flea Market  7.070948  125.613310
# 3                       Sencha             Café  7.073686  125.614290
# 4                  Happy Lemon  Bubble Tea Shop  7.077110  125.614416

# %%
venues2 = venues.drop(['Name','Category'],axis = 1)

# %%
venues2.values[:]
# Out:
# array([[  7.07227328, 125.61560031],
#        [  7.07210504, 125.61186758],
#        [  7.07094779, 125.61330967],
#        [  7.07368616, 125.61428991],
#        [  7.07711049, 125.614416  ],
#        [  7.07011551, 125.61408326],
#        [  7.06935284, 125.61329037],
#        [  7.07598374, 125.61316326],
#        [  7.07665284, 125.61458877],
#        [  7.07051974, 125.61540659],
#        [  7.0717783 , 125.61549   ],
#        [  7.06625741, 125.6170138 ],
#        [  7.07280371, 125.61661282],
#        [  7.06849174, 125.61332684],
#        [  7.07081729, 125.61557028],
#        [  7.07527867, 125.61286114],
#        [  7.07622218, 125.61524152],
#        [  7.07816217, 125.61422827],
#        [  7.06963988, 125.60669779],
#        [  7.07137297, 125.61107781],
#        [  7.06794957, 125.60628029],
#        [  7.07558451, 125.61187902],
#        [  7.07142209, 125.60883522],
#        [  7.06745515, 125.60692918],
#        [  7.07729022, 125.61430629],
#        [  7.07667459, 125.61678423],
#        [  7.06792634, 125.60833281],
#        [  7.0748352 , 125.61330266],
#        [  7.07385788, 125.60659819],
#        [  7.07678587, 125.60643647],
#        [  7.07221739, 125.61396652],
#        [  7.06637139, 125.60885003],
#        [  7.0766936 , 125.60812037],
#        [  7.07729945, 125.6079784 ],
#        [  7.07590645, 125.61141666],
#        [  7.07805785, 125.61333617],
#        [  7.07746749, 125.60750039],
#        [  7.06973454, 125.60512778],
#        [  7.06854859, 125.60677546],
#        [  7.07832378, 125.60917691],
#        [  7.06797752, 125.60622195],
#        [  7.06853912, 125.60626067],
#        [  7.07212117, 125.61131615],
#        [  7.07718302, 125.61442656],
#        [  7.07815942, 125.61419882],
#        [  7.07834916, 125.61353002],
#        [  7.07005374, 125.61427368],
#        [  7.07740347, 125.60779789],
#        [  7.07211068, 125.60741552],
#        [  7.0782443 , 125.61343842],
#        [  7.07817577, 125.614212  ],
#        [  7.07567003, 125.60666815],
#        [  7.07054632, 125.60754416],
#        [  7.07818   , 125.614295  ],
#        [  7.0716867 , 125.61073227],
#        [  7.07093445, 125.60750384],
#        [  7.07663774, 125.61482154],
#        [  7.06864607, 125.60593269],
#        [  7.08032587, 125.60980274],
#        [  7.06614391, 125.60970313],
#        [  7.06701152, 125.60863682],
#        [  7.0772204 , 125.61441091],
#        [  7.06850451, 125.61523589],
#        [  7.072115  , 125.60524   ],
#        [  7.07947507, 125.61448555],
#        [  7.0668919 , 125.61112883],
#        [  7.0719001 , 125.60528424],
#        [  7.07776287, 125.61425495],
#        [  7.07727142, 125.61445786],
#        [  7.0760408 , 125.60729896],
#        [  7.06926964, 125.60729668],
#        [  7.07907292, 125.60766935],
#        [  7.076162  , 125.606735  ],
#        [  7.07815474, 125.61369128],
#        [  7.06705405, 125.60865778],
#        [  7.07650039, 125.60610519],
#        [  7.07775495, 125.60744603],
#        [  7.07828767, 125.61415489],
#        [  7.0680051 , 125.60626555],
#        [  7.07901593, 125.60830395],
#        [  7.07734413, 125.61453911],
#        [  7.06629824, 125.60932804],
#        [  7.06860171, 125.6083421 ],
#        [  7.07816016, 125.61421884],
#        [  7.07622938, 125.61747337],
#        [  7.07372938, 125.61449431],
#        [  7.08089239, 125.61439399],
#        [  7.07516157, 125.61978361],
#        [  7.07941115, 125.60809457],
#        [  7.07769744, 125.61357525],
#        [  7.06794554, 125.60908153]])

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

X = venues2.values[:]
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[-0.32764854,  1.20637738],
#        [-0.36773473,  0.18033396],
#        [-0.64347196,  0.57673252],
#        [ 0.00899734,  0.8461771 ],
#        [ 0.82491077,  0.88083844],
#        [-0.84177902,  0.78937421],
#        [-1.02350029,  0.57142878],
#        [ 0.55643945,  0.53648851],
#        [ 0.71586567,  0.92832927],
#        [-0.74546449,  1.15312906],
#        [-0.44558718,  1.1760557 ],
#        [-1.76104618,  1.59491334],
#        [-0.20126435,  1.48469221],
#        [-1.22867365,  0.58145264],
#        [-0.6745673 ,  1.19812315],
#        [ 0.38844405,  0.45344268],
#        [ 0.61325421,  1.10775482],
#        [ 1.07549424,  0.82923527],
#        [-0.95510824, -1.24072223],
#        [-0.54216493, -0.03675454],
#        [-1.35785617, -1.35548299],
#        [ 0.46131645,  0.18347868],
#        [-0.53046198, -0.65319196],
#        [-1.47566137, -1.17711946],
#        [ 0.86773583,  0.85068142],
#        [ 0.72104805,  1.53180896],
#        [-1.36339085, -0.79129382],
#        [ 0.28277787,  0.57480588],
#        [ 0.04991357, -1.26810073],
#        [ 0.74756367, -1.31255415],
#        [-0.34096459,  0.75728499],
#        [-1.73388733, -0.64912158],
#        [ 0.72557898, -0.84968724],
#        [ 0.86993335, -0.88871175],
#        [ 0.53802553,  0.05638616],
#        [ 1.05063718,  0.58401616],
#        [ 0.90997393, -1.020106  ],
#        [-0.93255273, -1.67228281],
#        [-1.21512755, -1.21937408],
#        [ 1.11400164, -0.55926828],
#        [-1.35119725, -1.37152163],
#        [-1.21738479, -1.36087735],
#        [-0.36389243,  0.02876032],
#        [ 0.84219332,  0.88374147],
#        [ 1.07483781,  0.82113854],
#        [ 1.12004712,  0.63730235],
#        [-0.85649692,  0.84171619],
#        [ 0.89471817, -0.93832964],
#        [-0.36639146, -1.04343566],
#        [ 1.0950626 ,  0.61212205],
#        [ 1.07873372,  0.82476282],
#        [ 0.48169396, -1.24886903],
#        [-0.73913115, -1.00807501],
#        [ 1.07974218,  0.84757737],
#        [-0.46741149, -0.13173619],
#        [-0.64664994, -1.01915686],
#        [ 0.71226973,  0.99231238],
#        [-1.19190241, -1.45103194],
#        [ 1.5910368 , -0.38724323],
#        [-1.78809102, -0.41462225],
#        [-1.58136616, -0.7077279 ],
#        [ 0.8510979 ,  0.8794392 ],
#        [-1.22563235,  1.10620734],
#        [-0.36536186, -1.6414363 ],
#        [ 1.38831679,  0.89995626],
#        [-1.60986783, -0.0227318 ],
#        [-0.41656582, -1.6292748 ],
#        [ 0.98035345,  0.83656946],
#        [ 0.86325464,  0.89234399],
#        [ 0.57003537, -1.07547386],
#        [-1.0433243 , -1.07610228],
#        [ 1.29249777, -0.97366186],
#        [ 0.59891449, -1.23049479],
#        [ 1.07372358,  0.68162945],
#        [-1.57123264, -0.70196646],
#        [ 0.67954312, -1.40361653],
#        [ 0.9784657 , -1.03504858],
#        [ 1.10539776,  0.80906325],
#        [-1.34462569, -1.35953724],
#        [ 1.2789191 , -0.79922508],
#        [ 0.880581  ,  0.91467747],
#        [-1.75131807, -0.51772792],
#        [-1.20247125, -0.78874   ],
#        [ 1.07501528,  0.82664315],
#        [ 0.61497   ,  1.72123994],
#        [ 0.01929648,  0.90236248],
#        [ 1.72602242,  0.87478794],
#        [ 0.36054357,  2.35627055],
#        [ 1.37308722, -0.85677868],
#        [ 0.96476331,  0.64973493],
#        [-1.35881786, -0.58548572]])

# %%
# set number of clusters
vclusters = 5

venues_cluster = venues.drop('Name',1)
venues_cluster = venues_cluster.drop('Category',1)
venues_cluster.head()
# run k-means clustering
kmeans = KMeans(n_clusters=vclusters, random_state=0).fit(cluster_dataset)

# check cluster labels generated for each row in the dataframe
labels = kmeans.labels_

# %%
venues['Labels'] = labels

# %%
venues.head()
# Out:
#                           Name         Category  Latitude   Longitude  Labels
# 0  Harley Boulevard Motor Cafe            Diner  7.072273  125.615600       2
# 1                   Cafe Marco   Breakfast Spot  7.072105  125.611868       2
# 2           Roxas Night Market      Flea Market  7.070948  125.613310       2
# 3                       Sencha             Café  7.073686  125.614290       2
# 4                  Happy Lemon  Bubble Tea Shop  7.077110  125.614416       0

# %% [markdown]
# ### Schools cluster

# %%
schools.head()
# Out:
#                                        Name              Category  Latitude  \
# 0                        Holy Child College           High School  7.072679
# 1         Holy Cross Of Davao College, Inc.  College & University  7.076794
# 2  Holy Cross of Davao College Main Library       College Library  7.077259
# 3                  San Pedro College PL 412     College Classroom  7.077899
# 4                  San Pedro College CT 303     College Classroom  7.078021
#
#     Longitude
# 0  125.615595
# 1  125.614239
# 2  125.616127
# 3  125.615115
# 4  125.615649

# %%
schools2 = schools.drop(['Name','Category'],axis = 1)
schools2.values[:]
# Out:
# array([[  7.07267861, 125.61559526],
#        [  7.07679405, 125.61423887],
#        [  7.07725859, 125.61612701],
#        [  7.07789928, 125.61511465],
#        [  7.07802119, 125.61564866],
#        [  7.07812869, 125.61538166],
#        [  7.07811917, 125.6157074 ],
#        [  7.07810062, 125.61562437],
#        [  7.07862349, 125.60903736],
#        [  7.07817206, 125.61545119],
#        [  7.07806678, 125.61565165],
#        [  7.07815166, 125.61556202],
#        [  7.07796997, 125.61571314],
#        [  7.07806467, 125.61562868],
#        [  7.07234818, 125.61266884],
#        [  7.07245691, 125.61318684],
#        [  7.07067678, 125.61402798],
#        [  7.07403139, 125.61259941],
#        [  7.07393365, 125.61225763],
#        [  7.07134788, 125.61469812],
#        [  7.07091423, 125.61435334],
#        [  7.07395103, 125.6127703 ],
#        [  7.074209  , 125.61267   ],
#        [  7.07425343, 125.61368349],
#        [  7.07448244, 125.61277008],
#        [  7.07386789, 125.61160077],
#        [  7.07070874, 125.60740848],
#        [  7.07385562, 125.61522146],
#        [  7.0741124 , 125.61264065],
#        [  7.069059  , 125.614691  ],
#        [  7.07536697, 125.61342621],
#        [  7.07563837, 125.61104536],
#        [  7.076509  , 125.612167  ],
#        [  7.068988  , 125.609563  ],
#        [  7.073939  , 125.617567  ],
#        [  7.07797299, 125.61504523],
#        [  7.07666   , 125.61541   ],
#        [  7.07682448, 125.61654579],
#        [  7.07722998, 125.61482239],
#        [  7.0677423 , 125.609825  ],
#        [  7.076903  , 125.61569   ],
#        [  7.07137585, 125.60758972],
#        [  7.076898  , 125.616118  ],
#        [  7.0772295 , 125.61559296],
#        [  7.066941  , 125.611478  ],
#        [  7.077397  , 125.61556   ],
#        [  7.077622  , 125.6151    ],
#        [  7.076909  , 125.616559  ],
#        [  7.077368  , 125.615835  ],
#        [  7.07678699, 125.61659241]])

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

Y = schools2.values[:]
Y = np.nan_to_num(Y)
cluster_dataset2 = StandardScaler().fit_transform(Y)
cluster_dataset2
# Out:
# array([[-0.77144948,  0.6901655 ],
#        [ 0.56670259,  0.10871902],
#        [ 0.7177485 ,  0.91811162],
#        [ 0.9260735 ,  0.48414228],
#        [ 0.965713  ,  0.7130569 ],
#        [ 1.00066634,  0.59859978],
#        [ 0.99757017,  0.73823741],
#        [ 0.99153954,  0.70264239],
#        [ 1.16155241, -2.12101305],
#        [ 1.01476944,  0.62840463],
#        [ 0.98053705,  0.71433715],
#        [ 1.00813383,  0.67591496],
#        [ 0.94905746,  0.74069792],
#        [ 0.97985082,  0.70449172],
#        [-0.87889033, -0.56430608],
#        [-0.8435365 , -0.34225213],
#        [-1.42235339,  0.01831659],
#        [-0.33158754, -0.59406599],
#        [-0.36336806, -0.74057672],
#        [-1.20414192,  0.30558782],
#        [-1.34514706,  0.15779078],
#        [-0.35771873, -0.52081086],
#        [-0.27383736, -0.56380791],
#        [-0.25938962, -0.12935638],
#        [-0.1849269 , -0.52090633],
#        [-0.38474983, -1.02215378],
#        [-1.41196031, -2.81926472],
#        [-0.38874041,  0.52992533],
#        [-0.30524804, -0.5763881 ],
#        [-1.94838127,  0.3025349 ],
#        [ 0.10268266, -0.23964373],
#        [ 0.19092791, -1.26024269],
#        [ 0.4740172 , -0.7794291 ],
#        [-1.97146721, -1.89568673],
#        [-0.36162898,  1.53539087],
#        [ 0.95004039,  0.45438327],
#        [ 0.52311548,  0.6107489 ],
#        [ 0.57659663,  1.09763004],
#        [ 0.70844576,  0.35885691],
#        [-2.37651175, -1.7833751 ],
#        [ 0.60212794,  0.7307766 ],
#        [-1.19504888, -2.74157267],
#        [ 0.60050217,  0.91424751],
#        [ 0.70829072,  0.68917694],
#        [-2.63705777, -1.07478298],
#        [ 0.7627541 ,  0.67504945],
#        [ 0.83591378,  0.47786108],
#        [ 0.60407887,  1.10329115],
#        [ 0.75332463,  0.7929338 ],
#        [ 0.56440841,  1.11761183]])

# %%
# set number of clusters
sclusters = 5

# run k-means clustering
kmeans2 = KMeans(n_clusters=sclusters, random_state=0).fit(cluster_dataset2)

# check cluster labels generated for each row in the dataframe
labels2 = kmeans2.labels_

# %%
schools['Labels'] = labels2

# %% [markdown]
# # Visualizing the clusters
#
# ##### Only visualizing the cluster of the schools

# %%
heatlatlong = []

for x,y in zip(venuelat,venuelong):
    z = [x,y]
    heatlatlong.append(z)

# %%
# create map
lat2 = 7.0720
long2 = 125.6132

map_clusters = folium.Map(location=[lat2, long2], zoom_start=15)

# set color scheme for the clusters
x = np.arange(sclusters)
ys = [i + x + (i*x)**2 for i in range(sclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster,name in zip(schools['Latitude'], schools['Longitude'], schools['Labels'], schools['Name']):
    label = folium.Popup(str(name)+ ' ' + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_opacity=0.7).add_to(map_clusters)
    
for lat, lon, cluster,name in zip(venues['Latitude'], venues['Longitude'], venues['Labels'], venues['Name']):
    label = folium.Popup(str(name)+ '  ' + 'Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=6,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.7).add_to(map_clusters)
    

       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_349199f4f21b4e6fa3ed0c0d04c7cb90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_349199f4f21b4e6fa3ed0c0d04c7cb90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_349199f4f21b4e6fa3ed0c0d04c7cb90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_349199f4f21b4e6fa3ed0c0d04c7cb90%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B7.072%2C%20125.6132%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### Visuals using heatmap

# %%
from folium import plugins
from folium.plugins import HeatMap
map_dvo1 = folium.Map(location=[lat2,long2], zoom_start=13)
folium.TileLayer('cartodbpositron').add_to(map_dvo1) #cartodbpositron cartodbdark_matter
# set color scheme for the clusters
x = np.arange(sclusters)
ys = [i + x + (i*x)**2 for i in range(sclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster,name in zip(schools['Latitude'], schools['Longitude'], schools['Labels'], schools['Name']):
    label = folium.Popup(str(name)+ ' ' + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_opacity=0.7).add_to(map_dvo1)
    
for lat, lon, cluster,name in zip(venues['Latitude'], venues['Longitude'], venues['Labels'], venues['Name']):
    label = folium.Popup(str(name)+ '  ' + 'Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=3,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.7).add_to(map_dvo1)
    
HeatMap(heatlatlong).add_to(map_dvo1)
folium.Marker([lat2,long2]).add_to(map_dvo1)

map_dvo1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_07c8e9f07c7548bc8140d943c2e9beff%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_07c8e9f07c7548bc8140d943c2e9beff%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_07c8e9f07c7548bc8140d943c2e9beff%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_07c8e9f07c7548bc8140d943c2e9beff%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %% [markdown]
# ### Results and discussions
#
# From the heatmap visualization, we are able to identify that cluster 4 (orange) is the area with the most number of venues that would be interesting for college students. Cluster 4 is also home to 3 different colleges: a.) San Pedro College, b.) Holy Cross College, and C.) Samson Polytechnic College of Davao. If we take a closer look at the hotzone of cluster 4, we can see that it is due to the presence of a mall in the area, which largely contributes to the heightened number of venues in the cluster.
#
# The next cluster of interest is cluster 3 (teal). The cluster is home to 4 different colleges: a.) University of Mindanao, b.) Saint Albans College of Technology, c.) Davao Doctors College, and d.) Metro College Davao. In this cluster, there is also a considerable amount of restaurants and diners.
#
# Unlike the prior clusters, clusters 0 (red), 1 (purple), and  2 (lightblue) possess a less dense distribution of venues in their vicinity, this means that tenants could expect a greater amount of travel time should they live in this vicinity and a less amount of choices.

# %% [markdown]
# ### Conclusion
#
# This study was performed to help interested parties in identfying the best areas to open or rent a dormitory/apartment. The Foursquare API was used to obtain data about schools and interesting venues in downtown Davao, and clustering was used to segment the schools into different clusters to allow for interested parties to easily identify the number of colleges their dormitories could server should they choose to settle in a cluster.
#
# The cluster with the most dense hotzone is cluster 4, while the cluster with the most number of schools is cluster 3. But I believe, cluster 4 is the better choice in selecting an area for a dormitory since the distance between the colleges is much more tighter compared to those in cluster 3.
